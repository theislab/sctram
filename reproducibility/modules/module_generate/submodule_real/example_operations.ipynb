# %% [markdown]
# # Example Use Case

# %%
# %load_ext autoreload
# %autoreload 2

# %%
working_directory = "/Users/kemalinecik/git_nosync/sctram"

# %%
import sys
sys.path.append(working_directory)

import scanpy as sc
from sctram.generate.real import (
    sc_norman_sciplex_cpa, 
    sc_suo_developmental_complete,
    sc_he_developmental_complete,
    sc_garcia_developmental_complete,
    sc_braun_developmental_complete,
    sc_miller_developmental_complete,
    sc_kanemaru_developmental_complete,
)

# %%
# Note that the downloads are made into this directory. 
# Change it if needed using dataset_dir.
print("original 'dataset_dir': ", sc.settings.datasetdir)

dataset_dir = "/Users/kemalinecik/git_nosync/sctram/__temp__/data"
# Out:
# original 'dataset_dir':  /Users/kemalinecik/git_nosync/sctram/reproducibility/modules/module_generate/submodule_real/data

# %%
adata_norman = sc_norman_sciplex_cpa(dataset_dir=dataset_dir)
adata_norman
# Out:
# INFO:downloader:Detected Google Drive URL. Using gdown for download.
# Downloading...
# From (original): https://drive.google.com/uc?id=1nWZ64abGDFLwhFCaEQUH02f3U5I-t51v
# From (redirected): https://drive.google.com/uc?id=1nWZ64abGDFLwhFCaEQUH02f3U5I-t51v&confirm=t&uuid=260eae61-5107-4653-adee-8b11d9486aab
# To: /Users/kemalinecik/git_nosync/sctram/__temp__/data/norman_sciplex_cpa.part
# 100%|██████████| 179M/179M [00:21<00:00, 8.39MB/s]
# INFO:downloader:Downloaded PosixPath('/Users/kemalinecik/git_nosync/sctram/__temp__/data/norman_sciplex_cpa.h5ad') successfully.
# AnnData object with n_obs × n_vars = 14811 × 4999
#     obs: 'sample', 'size_factor', 'n.umi', 'hash_umis', 'pval', 'qval', 'top_to_second_best_ratio', 'top_oligo', 'drug', 'dose', 'vehicle', 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'product_dose', 'louvain', 'dose_val', 'cell_type', 'drug_dose_name', 'cov_drug_dose_name', 'condition', 'control', 'split', 'dose_training', '_scvi_batch', '_scvi_labels'
# ...

# %%
adata_suo = sc_suo_developmental_complete(dataset_dir=dataset_dir)
adata_suo
# Out:
# INFO:downloader:Detected Google Drive URL. Using gdown for download.
# Downloading...
# From (original): https://drive.google.com/uc?id=1d_tTFEWoKfL-zPAs6D8KVeQr0dU4NhCU
# From (redirected): https://drive.google.com/uc?id=1d_tTFEWoKfL-zPAs6D8KVeQr0dU4NhCU&confirm=t&uuid=d71b5f80-406d-4d5b-a3dd-83e5016752d0
# To: /Users/kemalinecik/git_nosync/sctram/__temp__/data/suo_developmental_complete.part
# 100%|██████████| 2.36G/2.36G [05:40<00:00, 6.91MB/s]
# INFO:downloader:Downloaded PosixPath('/Users/kemalinecik/git_nosync/sctram/__temp__/data/suo_developmental_complete.h5ad') successfully.
# AnnData object with n_obs × n_vars = 841922 × 8192
#     obs: 'sample_ID', 'organ', 'age', 'cell_type', 'sex', 'sex_inferred', 'concatenated_integration_covariates', 'integration_donor', 'integration_biological_unit', 'integration_sample_status', 'integration_library_platform_coarse', 'n_genes', '_scvi_batch', '_scvi_labels', 'LVL3', 'LVL2', 'LVL1', 'LVL0'
# ...

# %%
adata_miller = sc_miller_developmental_complete(dataset_dir=dataset_dir)
adata_miller
# Out:
# INFO:downloader:Detected Google Drive URL. Using gdown for download.
# Downloading...
# From: https://drive.google.com/uc?id=1aOQXRWzkgjchW_WUynlYzkVWWat8qyQW
# To: /Users/kemalinecik/git_nosync/sctram/__temp__/data/miller_developmental_complete.part
# 100%|██████████| 35.8M/35.8M [00:05<00:00, 6.48MB/s]
# INFO:downloader:Downloaded PosixPath('/Users/kemalinecik/git_nosync/sctram/__temp__/data/miller_developmental_complete.h5ad') successfully.
# AnnData object with n_obs × n_vars = 7405 × 8192
#     obs: 'sample_ID', 'organ', 'age', 'cell_type', 'sex', 'sex_inferred', 'concatenated_integration_covariates', 'integration_donor', 'integration_biological_unit', 'integration_sample_status', 'integration_library_platform_coarse', 'n_genes', 'LVL3', 'LVL2', 'LVL1', 'LVL0', '_scvi_batch', '_scvi_labels'
#     uns: 'metrics', 'neighbors', 'rank_genes_groups', 'umap'
#     obsm: 'Unintegrated', 'X_pca', 'X_umap', 'harmony', 'scvi'
#     obsp: 'connectivities', 'distances'

# %%
adata_garcia = sc_garcia_developmental_complete(dataset_dir=dataset_dir)
adata_garcia
# Out:
# INFO:downloader:Detected Google Drive URL. Using gdown for download.
# Downloading...
# From (original): https://drive.google.com/uc?id=1z1u_mc8ou9G_jkK5T3SfJjSd1Vt57H-5
# From (redirected): https://drive.google.com/uc?id=1z1u_mc8ou9G_jkK5T3SfJjSd1Vt57H-5&confirm=t&uuid=e127f369-171b-416f-9b36-a7b6eebc83f1
# To: /Users/kemalinecik/git_nosync/sctram/__temp__/data/garcia_developmental_complete.part
# 100%|██████████| 697M/697M [01:52<00:00, 6.20MB/s]
# INFO:downloader:Downloaded PosixPath('/Users/kemalinecik/git_nosync/sctram/__temp__/data/garcia_developmental_complete.h5ad') successfully.
# AnnData object with n_obs × n_vars = 219731 × 8192
#     obs: 'sample_ID', 'organ', 'age', 'cell_type', 'sex', 'sex_inferred', 'concatenated_integration_covariates', 'integration_donor', 'integration_biological_unit', 'integration_sample_status', 'integration_library_platform_coarse', 'n_genes', 'LVL3', 'LVL2', 'LVL1', 'LVL0', '_scvi_batch', '_scvi_labels'
# ...

# %%
adata_he = sc_he_developmental_complete(dataset_dir=dataset_dir)
adata_he
# Out:
# INFO:downloader:Detected Google Drive URL. Using gdown for download.
# Downloading...
# From (original): https://drive.google.com/uc?id=1Yhd-Nt5kGphZz1bYItJSRSAm-JVxm34J
# From (redirected): https://drive.google.com/uc?id=1Yhd-Nt5kGphZz1bYItJSRSAm-JVxm34J&confirm=t&uuid=bb64fb16-2017-4b24-a288-94bc0e3c5c52
# To: /Users/kemalinecik/git_nosync/sctram/__temp__/data/he_developmental_complete.part
# 100%|██████████| 299M/299M [01:04<00:00, 4.66MB/s]
# INFO:downloader:Downloaded PosixPath('/Users/kemalinecik/git_nosync/sctram/__temp__/data/he_developmental_complete.h5ad') successfully.
# AnnData object with n_obs × n_vars = 71650 × 8192
#     obs: 'sample_ID', 'organ', 'age', 'cell_type', 'sex', 'sex_inferred', 'concatenated_integration_covariates', 'integration_donor', 'integration_biological_unit', 'integration_sample_status', 'integration_library_platform_coarse', 'n_genes', 'LVL3', 'LVL2', 'LVL1', 'LVL0', '_scvi_batch', '_scvi_labels'
# ...

# %%
adata_kanemaru = sc_kanemaru_developmental_complete(dataset_dir=dataset_dir)
adata_kanemaru
# Out:
# INFO:downloader:Detected Google Drive URL. Using gdown for download.
# Downloading...
# From (original): https://drive.google.com/uc?id=1vjOBgzgUGIWqkdfVSiK8I9Wiv_oex3DK
# From (redirected): https://drive.google.com/uc?id=1vjOBgzgUGIWqkdfVSiK8I9Wiv_oex3DK&confirm=t&uuid=54b3cbc4-8b8c-4bc4-b101-cd2b785c03d2
# To: /Users/kemalinecik/git_nosync/sctram/__temp__/data/kanemaru_developmental_complete.part
# 100%|██████████| 309M/309M [01:02<00:00, 4.93MB/s]
# INFO:downloader:Downloaded PosixPath('/Users/kemalinecik/git_nosync/sctram/__temp__/data/kanemaru_developmental_complete.h5ad') successfully.
# AnnData object with n_obs × n_vars = 131636 × 8192
#     obs: 'sample_ID', 'organ', 'age', 'cell_type', 'sex', 'sex_inferred', 'concatenated_integration_covariates', 'integration_donor', 'integration_biological_unit', 'integration_sample_status', 'integration_library_platform_coarse', 'n_genes', 'LVL3', 'LVL2', 'LVL1', 'LVL0', '_scvi_batch', '_scvi_labels'
# ...

# %%
adata_braun = sc_braun_developmental_complete(dataset_dir=dataset_dir)
adata_braun
# Out:
# INFO:downloader:Detected Google Drive URL. Using gdown for download.
# Downloading...
# From (original): https://drive.google.com/uc?id=1RmqpDs0LjBlUlbX_SMWmC6I5Zd-KeuJh
# From (redirected): https://drive.google.com/uc?id=1RmqpDs0LjBlUlbX_SMWmC6I5Zd-KeuJh&confirm=t&uuid=55e4f22c-904d-456b-9435-9c6673e77087
# To: /Users/kemalinecik/git_nosync/sctram/__temp__/data/braun_developmental_complete.part
# 100%|██████████| 3.67G/3.67G [12:20<00:00, 4.96MB/s]
# INFO:downloader:Downloaded PosixPath('/Users/kemalinecik/git_nosync/sctram/__temp__/data/braun_developmental_complete.h5ad') successfully.
# AnnData object with n_obs × n_vars = 1661498 × 8192
#     obs: 'sample_ID', 'organ', 'age', 'cell_type', 'sex', 'sex_inferred', 'concatenated_integration_covariates', 'integration_donor', 'integration_biological_unit', 'integration_sample_status', 'integration_library_platform_coarse', 'n_genes', 'LVL3', 'LVL2', 'LVL1', 'LVL0', '_scvi_batch', '_scvi_labels'
# ...

# %% [markdown]
# ## Skips download if it is already downloaded.

# %%
adata_he = sc_he_developmental_complete(dataset_dir=dataset_dir)
adata_he
# Out:
# WARNING:downloader:File PosixPath('/Users/kemalinecik/git_nosync/sctram/__temp__/data/he_developmental_complete.h5ad') already exists. Skipping download.
# AnnData object with n_obs × n_vars = 71650 × 8192
#     obs: 'sample_ID', 'organ', 'age', 'cell_type', 'sex', 'sex_inferred', 'concatenated_integration_covariates', 'integration_donor', 'integration_biological_unit', 'integration_sample_status', 'integration_library_platform_coarse', 'n_genes', 'LVL3', 'LVL2', 'LVL1', 'LVL0', '_scvi_batch', '_scvi_labels'
#     uns: 'metrics', 'neighbors', 'rank_genes_groups', 'umap'
#     obsm: 'Unintegrated', 'X_pca', 'X_umap', 'harmony', 'scvi'
#     obsp: 'connectivities', 'distances'

# %%
adata_braun = sc_braun_developmental_complete(dataset_dir=dataset_dir)
adata_braun
# Out:
# WARNING:downloader:File PosixPath('/Users/kemalinecik/git_nosync/sctram/__temp__/data/braun_developmental_complete.h5ad') already exists. Skipping download.
# AnnData object with n_obs × n_vars = 1661498 × 8192
#     obs: 'sample_ID', 'organ', 'age', 'cell_type', 'sex', 'sex_inferred', 'concatenated_integration_covariates', 'integration_donor', 'integration_biological_unit', 'integration_sample_status', 'integration_library_platform_coarse', 'n_genes', 'LVL3', 'LVL2', 'LVL1', 'LVL0', '_scvi_batch', '_scvi_labels'
#     uns: 'metrics', 'neighbors', 'rank_genes_groups', 'umap'
#     obsm: 'Unintegrated', 'X_pca', 'X_umap', 'harmony', 'scvi'
#     obsp: 'connectivities', 'distances'
