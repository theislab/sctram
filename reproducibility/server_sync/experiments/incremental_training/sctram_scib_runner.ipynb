# %% [markdown]
# # Trajectory Analysis for Incremental Training

# %%
0
# Out:
# 0

# %%
import sys
working_directory = "/home/icb/kemal.inecik/work/codes/sctram"
sys.path.append(working_directory)

import logging
import subprocess
import gc
import os
import time
import numpy as np
import pandas as pd
import networkx as nx
import scanpy as sc
import anndata as ad
import pickle
import itertools
import torch
import tqdm
import scvi
import h5py

sc.settings.verbose = 3

# %%
from sctram.api._lower_level import TrajectoryEvaluationAPI
from sctram.generate.real import sc_suo_developmental_complete
from sctram.input import InputTrajectories
# Out:
# 2025-05-09 14:43:03.105 | INFO     | sctram.api._defaults_read:load_default_metrics:23 - Loaded default metrics from /home/icb/kemal.inecik/work/codes/sctram/sctram/api/_defaults.yaml
# 2025-05-09 14:43:03.106 | INFO     | sctram.api._defaults_read:load_default_metrics:79 - Default metrics YAML structure validated successfully.

# %%
# Important to have consistent figures across platforms

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import pickle

from networkx.drawing.nx_agraph import graphviz_layout
from matplotlib import gridspec
import matplotlib.pyplot as plt
import seaborn as sns
import colorcet as cc
from adjustText import adjust_text  
import matplotlib.patheffects as path_effects

_rcparams_path = os.path.join(working_directory, "reproducibility/figure_rcparams/rcparams.pickle")
with open(_rcparams_path, "rb") as file:
    _rcparams = pickle.load(file)
plt.rcParams.update(_rcparams)

# %%
print(f"CUDA used: {torch.cuda.is_available()}")

dataset_dir = "/home/icb/kemal.inecik/lustre_workspace/temp_sctram_data"
helpers_directory = os.path.join(os.getcwd(), "helper")
logs_directory = os.path.join(os.getcwd(), "logs")
# Out:
# CUDA used: True

# %% [markdown]
# ## Definitions

# %%
definitions = dict()

# %%
definitions["tardis_sciplex"] = {
    "training_anndata_path": os.path.join(dataset_dir, f"tardis_cpa_sciplex_v2_encode_incremental_training_anndata.h5ad"),
    "vae_path": os.path.join(dataset_dir, f"tardis_cpa_sciplex_v2_encode_incremental"),
    "pickle_paths_path": os.path.join(dataset_dir, f"tardis_cpa_sciplex_v2_encode_incremental_paths.pkl"),
    "trajectory_object_path": None,
    "label_obs_column": "drug_dose_name",
    "batch_obs_column": "sample",
    # "pickle_indices_path": os.path.join(dataset_dir, f"tardis_cpa_sciplex_v2_encode_incremental_latent_indices.pkl"),
}

# %%
definitions["scvi_garcia"] = {
    "training_anndata_path": os.path.join(dataset_dir, f"scvi_garcia_incremental_with_callback_training_anndata.h5ad"),
    "vae_path": os.path.join(dataset_dir, f"scvi_garcia_incremental_with_callback"),
    "pickle_paths_path": os.path.join(dataset_dir, f"scvi_garcia_incremental_with_callback_paths.pkl"),
    "trajectory_object_path": None,
    "label_obs_column": "ref_anno2",
    "batch_obs_column": "concatenated_integration_covariates",
}

# %%
definitions["scvi_dentategyrus"] = {
    "training_anndata_path": os.path.join(dataset_dir, f"scvi_dentategyrus_incremental_with_callback_training_anndata.h5ad"),
    "vae_path": os.path.join(dataset_dir, f"scvi_dentategyrus_incremental_with_callback"),
    "pickle_paths_path": os.path.join(dataset_dir, f"scvi_dentategyrus_incremental_with_callback_paths.pkl"),
    "trajectory_object_path": None,
    "label_obs_column": "ClusterName",
    "batch_obs_column": "SampleID",
}

# %% [markdown]
# ### Trajectory `tardis_sciplex`

# %%
with h5py.File(definitions["tardis_sciplex"]["training_anndata_path"]) as _file_anndata_training:
    adata_training_obs = ad.io.read_elem(_file_anndata_training["obs"])
with open(definitions["tardis_sciplex"]["pickle_paths_path"], "rb") as _file_pickle_paths:
    pickle_paths = pickle.load(_file_pickle_paths)
latent = ad.read_h5ad(pickle_paths[max(pickle_paths.keys())])
latent.obs = adata_training_obs.copy()
latent
# Out:
# AnnData object with n_obs × n_vars = 14811 × 40
#     obs: 'sample', 'size_factor', 'n.umi', 'hash_umis', 'pval', 'qval', 'top_to_second_best_ratio', 'top_oligo', 'drug', 'dose', 'vehicle', 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'product_dose', 'louvain', 'dose_val', 'cell_type', 'drug_dose_name', 'cov_drug_dose_name', 'condition', 'control', 'split', 'dose_training', '_scvi_batch', '_scvi_labels'

# %%
node_names = set(sorted(latent.obs[definitions["tardis_sciplex"]["label_obs_column"]].unique()))
ground_truth_trajectories = dict()

# %%
trajectory = "fork"
ground_truth_trajectories[trajectory] = [
    ('Vehicle_1.0', 'BMS_0.001'),
    ('Vehicle_1.0', 'Dex_0.001'),
    ('Vehicle_1.0', 'Nutlin_0.001'),
    
    ('BMS_0.001', 'BMS_0.005'),
    ('Dex_0.001', 'Dex_0.005'),
    ('Nutlin_0.001', 'Nutlin_0.005'),
    
    ('BMS_0.005', 'BMS_0.01'),
    ('Dex_0.005', 'Dex_0.01'),
    ('Nutlin_0.005', 'Nutlin_0.01'),
]
_input_trajectory = InputTrajectories(ground_truth_trajectories).get_trajectory(trajectory, include_additional_nodes=False)
_input_trajectory.plot_trajectory(
    title=trajectory,
    figsize=(15, 2), 
    label_offset=0,
)
assert all([i in node_names for i in _input_trajectory.nodes()])

# %%
trajectory = "linear"
ground_truth_trajectories[trajectory] = [
    ('Vehicle_1.0', 'Nutlin_0.001'),
    ('Nutlin_0.001', 'Nutlin_0.005'),
    ('Nutlin_0.005', 'Nutlin_0.01'),
    ('Nutlin_0.01', 'Nutlin_0.05'),
    ('Nutlin_0.05', 'Nutlin_0.1'),
    ('Nutlin_0.1', 'Nutlin_0.5'),
    ('Nutlin_0.5', 'Nutlin_1.0'),
]
_input_trajectory = InputTrajectories(ground_truth_trajectories).get_trajectory(trajectory, include_additional_nodes=False)
_input_trajectory.plot_trajectory(
    title=trajectory,
    figsize=(15, 2), 
    label_offset=0,
)

assert all([i in node_names for i in _input_trajectory.nodes()])

# %%
trajectory_object = InputTrajectories(ground_truth_trajectories)

definitions["tardis_sciplex"]["trajectory_object_path"] = os.path.join(dataset_dir, f"tardis_cpa_sciplex_v2_encode_incremental_trajectory_object.pkl")
with open(definitions["tardis_sciplex"]["trajectory_object_path"], "wb") as _f:
    pickle.dump(trajectory_object, _f, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Trajectory `scvi_garcia`

# %%
with h5py.File(definitions["scvi_garcia"]["training_anndata_path"]) as _file_anndata_training:
    adata_training_obs = ad.io.read_elem(_file_anndata_training["obs"])
with open(definitions["scvi_garcia"]["pickle_paths_path"], "rb") as _file_pickle_paths:
    pickle_paths = pickle.load(_file_pickle_paths)
latent = ad.read_h5ad(pickle_paths[max(pickle_paths.keys())])
latent.obs = adata_training_obs.copy()
latent
# Out:
# AnnData object with n_obs × n_vars = 26185 × 24
#     obs: 'LVL0', 'LVL1', 'LVL2', 'LVL3', 'age', 'anatomical_region', 'anatomical_region_level_2', 'author_batch', 'biological_unit', 'broad_anno', 'cell_enrichment', 'cell_type', 'concatenated_integration_covariates', 'doi', 'handle_anndata', 'institute', 'integration_biological_unit', 'integration_donor', 'integration_library_platform_coarse', 'integration_sample_status', 'lane_ID', 'leiden', 'library_platform', 'organ', 'original_author_annotation', 'protocol_tissue_dissociation', 'reads_processing', 'ref_anno1', 'ref_anno2', 'reference_genome', 'reference_genome_ensembl_release', 'sample_ID', 'sample_cultured', 'sample_status', 'sequencing_platform', 'sex', 'sex_inferred', 'strand_sequence', 'study', 'study_PI', 'subject_type', 'csv_key', '_scvi_batch', '_scvi_labels'

# %%
node_names = set(sorted(latent.obs[definitions["scvi_garcia"]["label_obs_column"]].unique()))
ground_truth_trajectories = dict()

trajectory = "germline"
ground_truth_trajectories[trajectory] = [
    ('PGC', 'GC'),
    ('GC', 'pre_spermatogonia'),
    ('GC', 'oogonia'),
    ('oogonia', 'oogonia_meiotic_1'),
    ('oogonia_meiotic_1', 'oogonia_meiotic_2'),
    ('oogonia_meiotic_2', 'pre_oocyte'),
    ('pre_oocyte', 'oocyte')
    
]
_input_trajectory = InputTrajectories(ground_truth_trajectories).get_trajectory(trajectory, include_additional_nodes=False)
_input_trajectory.plot_trajectory(
    title=trajectory,
    figsize=(15, 2), 
    label_offset=0,
)

assert all([i in node_names for i in _input_trajectory.nodes()])

# %%
trajectory_object = InputTrajectories(ground_truth_trajectories)

definitions["scvi_garcia"]["trajectory_object_path"] = os.path.join(dataset_dir, f"scvi_garcia_incremental_with_callback_trajectory_object.pkl")
with open(definitions["scvi_garcia"]["trajectory_object_path"], "wb") as _f:
    pickle.dump(trajectory_object, _f, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Trajectory `scvi_dentategyrus`

# %%
with h5py.File(definitions["scvi_dentategyrus"]["training_anndata_path"]) as _file_anndata_training:
    adata_training_obs = ad.io.read_elem(_file_anndata_training["obs"])
with open(definitions["scvi_dentategyrus"]["pickle_paths_path"], "rb") as _file_pickle_paths:
    pickle_paths = pickle.load(_file_pickle_paths)
latent = ad.read_h5ad(pickle_paths[max(pickle_paths.keys())])
latent.obs = adata_training_obs.copy()
latent
# Out:
# AnnData object with n_obs × n_vars = 18213 × 24
#     obs: 'Age', 'Cell_Conc', 'ChipID', 'ClusterName', 'Clusters', 'Comments', 'Date_Captured', 'DonorID', 'Label', 'NGI_PlateWell', 'Num_Pooled_Animals', 'PCR_Cycles', 'Plug_Date', 'Project', 'SampleID', 'SampleOK', 'Sample_Index', 'Seq_Comment', 'Seq_Lib_Date', 'Seq_Lib_Ok', 'Serial_Number', 'Sex', 'Species', 'Strain', 'TSNE1', 'TSNE2', 'Target_Num_Cells', 'Tissue', 'Transcriptome', 'cDNA_Lib_Ok', 'ngperul_cDNA', 'clusters', '_scvi_batch', '_scvi_labels'

# %%
node_names = set(sorted(latent.obs[definitions["scvi_dentategyrus"]["label_obs_column"]].unique()))
ground_truth_trajectories = dict()

# %%
trajectory = "complex"
ground_truth_trajectories[trajectory] = [
    ('Nbl2', 'CA'),
    ('Nbl2', 'ImmGranule1'),
    ('Nbl2', 'Nbl1'),
    ('ImmGranule1', 'ImmGranule2'),
    ('ImmGranule2', 'Granule'),
    ('CA', 'CA1-Sub'),
    ('CA', 'CA2-3-4'),
    ('Nbl1', 'RadialGlia'),
    ('Nbl1', 'nIPC'),
    ('RadialGlia', 'RadialGlia2'),
    ('RadialGlia2', 'ImmAstro'),
    ('nIPC', 'GlialProg'),
    ('GlialProg', 'OPC'),
]
_input_trajectory = InputTrajectories(ground_truth_trajectories).get_trajectory(trajectory, include_additional_nodes=False)
_input_trajectory.plot_trajectory(
    title=trajectory,
    figsize=(15, 2), 
    label_offset=0,
)

assert all([i in node_names for i in _input_trajectory.nodes()])

# %%
trajectory = "less_complex_1"
ground_truth_trajectories[trajectory] = [
    ('Nbl2', 'CA'),
    ('Nbl2', 'ImmGranule1'),
    ('Nbl2', 'Nbl1'),
    ('ImmGranule1', 'ImmGranule2'),
    ('ImmGranule2', 'Granule'),
    ('CA', 'CA1-Sub'),
    ('CA', 'CA2-3-4'),
    ('Nbl1', 'RadialGlia'),
    ('RadialGlia', 'RadialGlia2'),
    ('RadialGlia2', 'ImmAstro'),
]
_input_trajectory = InputTrajectories(ground_truth_trajectories).get_trajectory(trajectory, include_additional_nodes=False)
_input_trajectory.plot_trajectory(
    title=trajectory,
    figsize=(15, 2), 
    label_offset=0,
)

assert all([i in node_names for i in _input_trajectory.nodes()])

# %%
trajectory = "less_complex_2"
ground_truth_trajectories[trajectory] = [
    ('Nbl2', 'Nbl1'),
    ('Nbl1', 'RadialGlia'),
    ('Nbl1', 'nIPC'),
    ('RadialGlia', 'RadialGlia2'),
    ('RadialGlia2', 'ImmAstro'),
    ('nIPC', 'GlialProg'),
    ('GlialProg', 'OPC'),
]
_input_trajectory = InputTrajectories(ground_truth_trajectories).get_trajectory(trajectory, include_additional_nodes=False)
_input_trajectory.plot_trajectory(
    title=trajectory,
    figsize=(15, 2), 
    label_offset=0,
)

assert all([i in node_names for i in _input_trajectory.nodes()])

# %%
trajectory = "linear_1"
ground_truth_trajectories[trajectory] = [
    ('Nbl2', 'Nbl1'),
    ('Nbl1', 'RadialGlia'),
    ('RadialGlia', 'RadialGlia2'),
    ('RadialGlia2', 'ImmAstro'),
]
_input_trajectory = InputTrajectories(ground_truth_trajectories).get_trajectory(trajectory, include_additional_nodes=False)
_input_trajectory.plot_trajectory(
    title=trajectory,
    figsize=(15, 2), 
    label_offset=0,
)

assert all([i in node_names for i in _input_trajectory.nodes()])

# %%
trajectory_object = InputTrajectories(ground_truth_trajectories)

definitions["scvi_dentategyrus"]["trajectory_object_path"] = os.path.join(dataset_dir, f"scvi_dentategyrus_incremental_with_callback_trajectory_object.pkl")
with open(definitions["scvi_dentategyrus"]["trajectory_object_path"], "wb") as _f:
    pickle.dump(trajectory_object, _f, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Check Definitions

# %%
definitions
# Out:
# {'tardis_sciplex': {'training_anndata_path': '/home/icb/kemal.inecik/lustre_workspace/temp_sctram_data/tardis_cpa_sciplex_v2_encode_incremental_training_anndata.h5ad',
#   'vae_path': '/home/icb/kemal.inecik/lustre_workspace/temp_sctram_data/tardis_cpa_sciplex_v2_encode_incremental',
#   'pickle_paths_path': '/home/icb/kemal.inecik/lustre_workspace/temp_sctram_data/tardis_cpa_sciplex_v2_encode_incremental_paths.pkl',
#   'trajectory_object_path': '/home/icb/kemal.inecik/lustre_workspace/temp_sctram_data/tardis_cpa_sciplex_v2_encode_incremental_trajectory_object.pkl',
#   'label_obs_column': 'drug_dose_name',
#   'batch_obs_column': 'sample'},
#  'scvi_garcia': {'training_anndata_path': '/home/icb/kemal.inecik/lustre_workspace/temp_sctram_data/scvi_garcia_incremental_with_callback_training_anndata.h5ad',
#   'vae_path': '/home/icb/kemal.inecik/lustre_workspace/temp_sctram_data/scvi_garcia_incremental_with_callback',
#   'pickle_paths_path': '/home/icb/kemal.inecik/lustre_workspace/temp_sctram_data/scvi_garcia_incremental_with_callback_paths.pkl',
#   'trajectory_object_path': '/home/icb/kemal.inecik/lustre_workspace/temp_sctram_data/scvi_garcia_incremental_with_callback_trajectory_object.pkl',
#   'label_obs_column': 'ref_anno2',
#   'batch_obs_column': 'concatenated_integration_covariates'},
#  'scvi_dentategyrus': {'training_anndata_path': '/home/icb/kemal.inecik/lustre_workspace/temp_sctram_data/scvi_dentategyrus_incremental_with_callback_training_anndata.h5ad',
#   'vae_path': '/home/icb/kemal.inecik/lustre_workspace/temp_sctram_data/scvi_dentategyrus_incremental_with_callback',
#   'pickle_paths_path': '/home/icb/kemal.inecik/lustre_workspace/temp_sctram_data/scvi_dentategyrus_incremental_with_callback_paths.pkl',
#   'trajectory_object_path': '/home/icb/kemal.inecik/lustre_workspace/temp_sctram_data/scvi_dentategyrus_incremental_with_callback_trajectory_object.pkl',
#   'label_obs_column': 'ClusterName',
#   'batch_obs_column': 'SampleID'}}

# %% [markdown]
# # Running the benchmarking

# %% [markdown]
# ```
# #SBATCH -J {slurmjob_name}
# #SBATCH -p cpu_p
# #SBATCH --qos cpu_normal
# #SBATCH -c 8
# #SBATCH --mem=293G
# #SBATCH --nice=0
# #SBATCH -t 11:50:00
# #SBATCH -o {log_file}
# #SBATCH -e {log_file}
#
# #SBATCH -J {slurmjob_name}
# #SBATCH -p gpu_p
# #SBATCH --qos=gpu_normal
# #SBATCH --gres=gpu:1
# #SBATCH -c 6
# #SBATCH --mem=293G
# #SBATCH --nice=0
# #SBATCH -t 11:50:00
# #SBATCH -o {log_file}
# #SBATCH -e {log_file}
# ```

# %% [markdown]
# - for each step
# - for each trajectory

# %% [markdown]
# ### `scTRAM` package

# %%
override = False
count = 0

for run_id in definitions.keys():

    pickle_paths_path = definitions[run_id]["pickle_paths_path"]
    with open(pickle_paths_path, "rb") as _file_pickle_paths:
        steps_paths_dict = pickle.load(_file_pickle_paths)    
    trajectory_path = definitions[run_id]["trajectory_object_path"]
    training_anndata_path = definitions[run_id]["training_anndata_path"]
    label_obs_column = definitions[run_id]["label_obs_column"]
    
    for latent_step, latent_object_path in steps_paths_dict.items():
        
        with open(trajectory_path, "rb") as _file_trajectory_path:
            trajectories_object = pickle.load(_file_trajectory_path)
        
        for trajectory in sorted(trajectories_object.graph["trajectories"]):
            
            output_file_path = os.path.join(dataset_dir, f"metric_sctram_{run_id}_step_{latent_step}_trajectory_{trajectory}.pkl")
    
            log_file = os.path.join(logs_directory, f"slurm_out_metric_sctram_{run_id}_step_{latent_step}_trajectory_{trajectory}.log")
            slurmjob_name = f"sctram_{run_id}_{latent_step}_{trajectory}"
            if override or not os.path.exists(output_file_path) or not os.path.isfile(output_file_path):
                try:
                    slurm_script = f"""#!/bin/bash
#SBATCH -J {slurmjob_name}
#SBATCH -p cpu_p
#SBATCH --qos cpu_normal
#SBATCH -c 4
#SBATCH --mem=60G
#SBATCH --nice=0
#SBATCH -t 8:50:00
#SBATCH -o {log_file}
#SBATCH -e {log_file}

source activate sctram_dev_env
python -u {os.path.join(helpers_directory, 'incremental_sctram.py')} --training_anndata_path "{training_anndata_path}" --label_obs_column "{label_obs_column}" --run_id "{run_id}" --steps_paths_dict "{pickle_paths_path}" --latent_step "{latent_step}" --trajectory_path "{trajectory_path}" --trajectory "{trajectory}" 
"""
                    slurm_script_name = os.path.join(logs_directory, f"slurm_job_metric_sctram_{run_id}_step_{latent_step}_trajectory_{trajectory}.sh")
                    with open(slurm_script_name, "w") as _file_slurm_script:
                        _file_slurm_script.write(slurm_script)
                    
                    print(f"Submitted job: sctram {run_id!r} step {latent_step!r} trajectory {trajectory!r}")
                    subprocess.run(["sbatch", slurm_script_name])
                    count += 1
                    # if count > 2:
                    #     raise ValueError
                finally:
                    # time.sleep(0.1)
                    os.remove(slurm_script_name)
            else:
                print(f"Already exist: sctram {run_id!r} step {latent_step!r} trajectory {trajectory!r}")
print(f" - Number of jobs submitted: {count}")
# Out:
# Already exist: sctram 'tardis_sciplex' step 186 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 186 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 372 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 372 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 558 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 558 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 744 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 744 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 930 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 930 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1116 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1116 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1162 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1162 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1209 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1209 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1255 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1255 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1302 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1302 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1348 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1348 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1395 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1395 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1441 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1441 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1488 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1488 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1534 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1534 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1581 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1581 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1627 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1627 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1674 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1674 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1720 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1720 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1767 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1767 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1813 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1813 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1860 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1860 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1906 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1906 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1953 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1953 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 1999 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 1999 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2046 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2046 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2092 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2092 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2139 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2139 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2185 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2185 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2232 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2232 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2278 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2278 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2325 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2325 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2371 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2371 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2418 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2418 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2464 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2464 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2511 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2511 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2557 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2557 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2604 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2604 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2650 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2650 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2697 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2697 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2743 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2743 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2790 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2790 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2836 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2836 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2883 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2883 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2929 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2929 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 2976 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 2976 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3022 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3022 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3069 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3069 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3115 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3115 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3162 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3162 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3208 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3208 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3255 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3255 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3301 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3301 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3348 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3348 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3394 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3394 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3441 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3441 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3487 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3487 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3534 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3534 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3580 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3580 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3627 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3627 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3673 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3673 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3720 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3720 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3766 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3766 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3813 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3813 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3859 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3859 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3906 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3906 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3952 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3952 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 3999 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 3999 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4045 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4045 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4092 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4092 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4138 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4138 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4185 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4185 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4231 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4231 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4278 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4278 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4324 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4324 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4371 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4371 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4417 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4417 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4464 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4464 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4510 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4510 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4557 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4557 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4603 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4603 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4650 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4650 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4696 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4696 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4743 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4743 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4789 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4789 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4836 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4836 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4882 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4882 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4929 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4929 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 4975 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 4975 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5022 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5022 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5068 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5068 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5115 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5115 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5161 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5161 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5208 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5208 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5254 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5254 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5301 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5301 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5347 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5347 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5394 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5394 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5440 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5440 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5487 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5487 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5533 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5533 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5580 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5580 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5626 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5626 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5673 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5673 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5719 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5719 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5766 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5766 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5812 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5812 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5859 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5859 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5905 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5905 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5952 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5952 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 5998 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 5998 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6045 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6045 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6091 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6091 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6138 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6138 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6184 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6184 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6231 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6231 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6277 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6277 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6324 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6324 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6370 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6370 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6417 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6417 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6463 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6463 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6510 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6510 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6556 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6556 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6603 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6603 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6649 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6649 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6696 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6696 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6742 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6742 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6789 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6789 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6835 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6835 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6882 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6882 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6928 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6928 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 6975 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 6975 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7021 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7021 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7068 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7068 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7114 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7114 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7161 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7161 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7207 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7207 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7254 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7254 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7300 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7300 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7347 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7347 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7393 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7393 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7440 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7440 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7486 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7486 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7533 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7533 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7579 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7579 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7626 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7626 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7672 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7672 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7719 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7719 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7765 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7765 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7812 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7812 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7858 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7858 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7905 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7905 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7951 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7951 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 7998 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 7998 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8044 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8044 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8091 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8091 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8137 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8137 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8184 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8184 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8230 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8230 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8277 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8277 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8323 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8323 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8370 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8370 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8416 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8416 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8463 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8463 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8509 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8509 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8556 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8556 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8602 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8602 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8649 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8649 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8695 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8695 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8742 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8742 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8788 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8788 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8835 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8835 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8881 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8881 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8928 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8928 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 8974 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 8974 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9021 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9021 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9067 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9067 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9114 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9114 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9160 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9160 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9207 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9207 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9253 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9253 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9300 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9300 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9346 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9346 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9393 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9393 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9439 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9439 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9486 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9486 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9532 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9532 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9579 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9579 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9625 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9625 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9672 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9672 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9718 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9718 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9765 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9765 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9811 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9811 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9858 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9858 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9904 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9904 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9951 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9951 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 9997 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 9997 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10044 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10044 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10090 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10090 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10137 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10137 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10183 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10183 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10230 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10230 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10276 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10276 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10323 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10323 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10369 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10369 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10416 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10416 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10462 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10462 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10509 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10509 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10555 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10555 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10602 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10602 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10648 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10648 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10695 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10695 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10741 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10741 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10788 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10788 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10834 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10834 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10881 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10881 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10927 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10927 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 10974 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 10974 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11020 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11020 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11067 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11067 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11113 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11113 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11160 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11160 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11206 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11206 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11253 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11253 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11299 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11299 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11346 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11346 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11392 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11392 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11439 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11439 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11485 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11485 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11532 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11532 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11578 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11578 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11625 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11625 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11671 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11671 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11718 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11718 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11764 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11764 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11811 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11811 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11857 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11857 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11904 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11904 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11950 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11950 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 11997 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 11997 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12043 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12043 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12090 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12090 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12136 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12136 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12183 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12183 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12229 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12229 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12276 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12276 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12322 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12322 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12369 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12369 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12415 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12415 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12462 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12462 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12508 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12508 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12555 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12555 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12601 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12601 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12648 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12648 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12694 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12694 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12741 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12741 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12787 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12787 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12834 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12834 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12880 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12880 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12927 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12927 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 12973 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 12973 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13020 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13020 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13066 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13066 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13113 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13113 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13159 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13159 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13206 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13206 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13252 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13252 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13299 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13299 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13345 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13345 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13392 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13392 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13438 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13438 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13485 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13485 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13531 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13531 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13578 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13578 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13624 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13624 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13671 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13671 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13717 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13717 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13764 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13764 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13810 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13810 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13857 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13857 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13903 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13903 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13950 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13950 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 13996 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 13996 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14043 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14043 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14089 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14089 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14136 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14136 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14182 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14182 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14229 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14229 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14275 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14275 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14322 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14322 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14368 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14368 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14415 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14415 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14461 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14461 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14508 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14508 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14554 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14554 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14601 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14601 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14647 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14647 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14694 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14694 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14740 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14740 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14787 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14787 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14833 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14833 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14880 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14880 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14926 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14926 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 14973 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 14973 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15019 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15019 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15066 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15066 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15112 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15112 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15159 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15159 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15205 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15205 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15252 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15252 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15298 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15298 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15345 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15345 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15391 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15391 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15438 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15438 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15484 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15484 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15531 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15531 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15577 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15577 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15624 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15624 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15670 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15670 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15717 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15717 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15763 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15763 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15810 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15810 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15856 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15856 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15903 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15903 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15949 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15949 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 15996 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 15996 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 16042 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 16042 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 16089 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 16089 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 16135 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 16135 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 16182 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 16182 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 16228 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 16228 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 16275 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 16275 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 16321 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 16321 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 16368 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 16368 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 16414 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 16414 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 16461 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 16461 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 16507 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 16507 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 16554 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 16554 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 16600 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 16600 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 16647 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 16647 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 16693 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 16693 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 16740 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 16740 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 24180 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 24180 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 31620 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 31620 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 39060 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 39060 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 46500 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 46500 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 53940 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 53940 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 61380 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 61380 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 68820 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 68820 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 76260 trajectory 'fork'
# Already exist: sctram 'tardis_sciplex' step 76260 trajectory 'linear'
# Already exist: sctram 'tardis_sciplex' step 83700 trajectory 'fork'
# ...
# Already exist: sctram 'scvi_dentategyrus' step 377 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 377 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 377 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 377 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 391 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 391 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 391 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 391 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 406 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 406 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 406 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 406 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 420 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 420 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 420 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 420 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 435 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 435 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 435 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 435 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 449 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 449 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 449 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 449 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 464 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 464 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 464 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 464 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 478 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 478 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 478 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 478 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 493 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 493 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 493 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 493 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 507 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 507 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 507 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 507 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 522 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 522 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 522 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 522 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 536 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 536 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 536 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 536 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 551 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 551 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 551 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 551 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 565 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 565 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 565 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 565 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 580 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 580 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 580 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 580 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 870 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 870 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 870 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 870 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 1160 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 1160 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 1160 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 1160 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 1450 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 1450 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 1450 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 1450 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 1740 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 1740 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 1740 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 1740 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 2030 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 2030 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 2030 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 2030 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 2320 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 2320 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 2320 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 2320 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 2610 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 2610 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 2610 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 2610 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 2900 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 2900 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 2900 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 2900 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 3190 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 3190 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 3190 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 3190 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 3480 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 3480 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 3480 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 3480 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 3770 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 3770 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 3770 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 3770 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 4060 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 4060 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 4060 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 4060 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 4350 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 4350 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 4350 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 4350 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 4640 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 4640 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 4640 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 4640 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 4930 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 4930 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 4930 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 4930 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 5220 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 5220 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 5220 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 5220 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 5510 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 5510 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 5510 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 5510 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 5800 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 5800 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 5800 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 5800 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 6090 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 6090 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 6090 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 6090 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 6380 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 6380 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 6380 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 6380 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 6670 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 6670 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 6670 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 6670 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 6960 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 6960 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 6960 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 6960 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 7250 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 7250 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 7250 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 7250 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 7540 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 7540 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 7540 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 7540 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 7830 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 7830 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 7830 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 7830 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 8120 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 8120 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 8120 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 8120 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 8410 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 8410 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 8410 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 8410 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 8700 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 8700 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 8700 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 8700 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 8990 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 8990 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 8990 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 8990 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 9280 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 9280 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 9280 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 9280 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 9570 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 9570 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 9570 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 9570 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 9860 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 9860 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 9860 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 9860 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 10150 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 10150 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 10150 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 10150 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 10440 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 10440 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 10440 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 10440 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 10730 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 10730 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 10730 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 10730 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 11020 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 11020 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 11020 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 11020 trajectory 'linear_1'
# Already exist: sctram 'scvi_dentategyrus' step 11310 trajectory 'complex'
# Already exist: sctram 'scvi_dentategyrus' step 11310 trajectory 'less_complex_1'
# Already exist: sctram 'scvi_dentategyrus' step 11310 trajectory 'less_complex_2'
# Already exist: sctram 'scvi_dentategyrus' step 11310 trajectory 'linear_1'
#  - Number of jobs submitted: 0

# %% [markdown]
# ### `scIB` package

# %%
override = False
count = 0

for run_id in definitions.keys():

    pickle_paths_path = definitions[run_id]["pickle_paths_path"]
    with open(pickle_paths_path, "rb") as _file_pickle_paths:
        steps_paths_dict = pickle.load(_file_pickle_paths)    
    trajectory_path = definitions[run_id]["trajectory_object_path"]
    training_anndata_path = definitions[run_id]["training_anndata_path"]
    label_obs_column = definitions[run_id]["label_obs_column"]
    batch_obs_column = definitions[run_id]["batch_obs_column"]
    
    for latent_step, latent_object_path in steps_paths_dict.items():
        
        with open(trajectory_path, "rb") as _file_trajectory_path:
            trajectories_object = pickle.load(_file_trajectory_path)

        trajectories = sorted(trajectories_object.graph["trajectories"])
        trajectories += ["all_data_included"]
        
        for trajectory in trajectories:
            
            output_file_path = os.path.join(dataset_dir, f"metric_scib_{run_id}_step_{latent_step}_trajectory_{trajectory}.pkl")
    
            log_file = os.path.join(logs_directory, f"slurm_out_metric_scib_{run_id}_step_{latent_step}_trajectory_{trajectory}.log")
            slurmjob_name = f"scib_{run_id}_{latent_step}_{trajectory}"
            if override or not os.path.exists(output_file_path) or not os.path.isfile(output_file_path):
                try:
                    slurm_script = f"""#!/bin/bash
#SBATCH -J {slurmjob_name}
#SBATCH -p cpu_p
#SBATCH --qos cpu_normal
#SBATCH -c 8
#SBATCH --mem=60G
#SBATCH --nice=0
#SBATCH -t 8:50:00
#SBATCH -o {log_file}
#SBATCH -e {log_file}

source activate sctram_dev_env
python -u {os.path.join(helpers_directory, 'incremental_scib.py')} --training_anndata_path "{training_anndata_path}" --batch_obs_column "{batch_obs_column}" --label_obs_column "{label_obs_column}" --run_id "{run_id}" --steps_paths_dict "{pickle_paths_path}" --latent_step "{latent_step}" --trajectory_path "{trajectory_path}" --trajectory "{trajectory}" 
"""
                    slurm_script_name = os.path.join(logs_directory, f"slurm_job_metric_scib_{run_id}_step_{latent_step}_trajectory_{trajectory}.sh")
                    with open(slurm_script_name, "w") as _file_slurm_script:
                        _file_slurm_script.write(slurm_script)
                    
                    print(f"Submitted job: scib {run_id!r} step {latent_step!r} trajectory {trajectory!r}")
                    subprocess.run(["sbatch", slurm_script_name])
                    count += 1
                    # if count > 2:
                    #     raise ValueError
                finally:
                    # time.sleep(0.1)
                    os.remove(slurm_script_name)
                    pass
            else:
                print(f"Already exist: scib {run_id!r} step {latent_step!r} trajectory {trajectory!r}")
print(f" - Number of jobs submitted: {count}")
# Out:
# Submitted job: scib 'tardis_sciplex' step 186 trajectory 'fork'
# Submitted batch job 35990851
# Submitted job: scib 'tardis_sciplex' step 186 trajectory 'linear'
# Submitted batch job 35990852
# Submitted job: scib 'tardis_sciplex' step 186 trajectory 'all_data_included'
# Submitted batch job 35990853
# Submitted job: scib 'tardis_sciplex' step 372 trajectory 'fork'
# Submitted batch job 35990854
# Submitted job: scib 'tardis_sciplex' step 372 trajectory 'linear'
# Submitted batch job 35990855
# Submitted job: scib 'tardis_sciplex' step 372 trajectory 'all_data_included'
# Submitted batch job 35990856
# Submitted job: scib 'tardis_sciplex' step 558 trajectory 'fork'
# Submitted batch job 35990857
# Submitted job: scib 'tardis_sciplex' step 558 trajectory 'linear'
# Submitted batch job 35990858
# Submitted job: scib 'tardis_sciplex' step 558 trajectory 'all_data_included'
# Submitted batch job 35990859
# Submitted job: scib 'tardis_sciplex' step 744 trajectory 'fork'
# Submitted batch job 35990860
# Submitted job: scib 'tardis_sciplex' step 744 trajectory 'linear'
# Submitted batch job 35990861
# Submitted job: scib 'tardis_sciplex' step 744 trajectory 'all_data_included'
# Submitted batch job 35990862
# Submitted job: scib 'tardis_sciplex' step 930 trajectory 'fork'
# Submitted batch job 35990863
# Submitted job: scib 'tardis_sciplex' step 930 trajectory 'linear'
# Submitted batch job 35990864
# Submitted job: scib 'tardis_sciplex' step 930 trajectory 'all_data_included'
# Submitted batch job 35990865
# Submitted job: scib 'tardis_sciplex' step 1116 trajectory 'fork'
# Submitted batch job 35990866
# Submitted job: scib 'tardis_sciplex' step 1116 trajectory 'linear'
# Submitted batch job 35990867
# Submitted job: scib 'tardis_sciplex' step 1116 trajectory 'all_data_included'
# Submitted batch job 35990868
# Submitted job: scib 'tardis_sciplex' step 1162 trajectory 'fork'
# Submitted batch job 35990869
# Submitted job: scib 'tardis_sciplex' step 1162 trajectory 'linear'
# Submitted batch job 35990870
# Submitted job: scib 'tardis_sciplex' step 1162 trajectory 'all_data_included'
# Submitted batch job 35990871
# Submitted job: scib 'tardis_sciplex' step 1209 trajectory 'fork'
# Submitted batch job 35990872
# Submitted job: scib 'tardis_sciplex' step 1209 trajectory 'linear'
# Submitted batch job 35990873
# Submitted job: scib 'tardis_sciplex' step 1209 trajectory 'all_data_included'
# Submitted batch job 35990874
# Submitted job: scib 'tardis_sciplex' step 1255 trajectory 'fork'
# Submitted batch job 35990875
# Submitted job: scib 'tardis_sciplex' step 1255 trajectory 'linear'
# Submitted batch job 35990876
# Submitted job: scib 'tardis_sciplex' step 1255 trajectory 'all_data_included'
# Submitted batch job 35990877
# Submitted job: scib 'tardis_sciplex' step 1302 trajectory 'fork'
# Submitted batch job 35990878
# Submitted job: scib 'tardis_sciplex' step 1302 trajectory 'linear'
# Submitted batch job 35990879
# Submitted job: scib 'tardis_sciplex' step 1302 trajectory 'all_data_included'
# Submitted batch job 35990880
# Submitted job: scib 'tardis_sciplex' step 1348 trajectory 'fork'
# Submitted batch job 35990881
# Submitted job: scib 'tardis_sciplex' step 1348 trajectory 'linear'
# Submitted batch job 35990882
# Submitted job: scib 'tardis_sciplex' step 1348 trajectory 'all_data_included'
# Submitted batch job 35990883
# Submitted job: scib 'tardis_sciplex' step 1395 trajectory 'fork'
# Submitted batch job 35990884
# Submitted job: scib 'tardis_sciplex' step 1395 trajectory 'linear'
# Submitted batch job 35990885
# Submitted job: scib 'tardis_sciplex' step 1395 trajectory 'all_data_included'
# Submitted batch job 35990886
# Submitted job: scib 'tardis_sciplex' step 1441 trajectory 'fork'
# Submitted batch job 35990887
# Submitted job: scib 'tardis_sciplex' step 1441 trajectory 'linear'
# Submitted batch job 35990888
# Submitted job: scib 'tardis_sciplex' step 1441 trajectory 'all_data_included'
# Submitted batch job 35990889
# Submitted job: scib 'tardis_sciplex' step 1488 trajectory 'fork'
# Submitted batch job 35990890
# Submitted job: scib 'tardis_sciplex' step 1488 trajectory 'linear'
# Submitted batch job 35990891
# Submitted job: scib 'tardis_sciplex' step 1488 trajectory 'all_data_included'
# Submitted batch job 35990892
# Submitted job: scib 'tardis_sciplex' step 1534 trajectory 'fork'
# Submitted batch job 35990893
# Submitted job: scib 'tardis_sciplex' step 1534 trajectory 'linear'
# Submitted batch job 35990894
# Submitted job: scib 'tardis_sciplex' step 1534 trajectory 'all_data_included'
# Submitted batch job 35990895
# Submitted job: scib 'tardis_sciplex' step 1581 trajectory 'fork'
# Submitted batch job 35990896
# Submitted job: scib 'tardis_sciplex' step 1581 trajectory 'linear'
# Submitted batch job 35990897
# Submitted job: scib 'tardis_sciplex' step 1581 trajectory 'all_data_included'
# Submitted batch job 35990898
# Submitted job: scib 'tardis_sciplex' step 1627 trajectory 'fork'
# Submitted batch job 35990899
# Submitted job: scib 'tardis_sciplex' step 1627 trajectory 'linear'
# Submitted batch job 35990900
# Submitted job: scib 'tardis_sciplex' step 1627 trajectory 'all_data_included'
# Submitted batch job 35990901
# Submitted job: scib 'tardis_sciplex' step 1674 trajectory 'fork'
# Submitted batch job 35990902
# Submitted job: scib 'tardis_sciplex' step 1674 trajectory 'linear'
# Submitted batch job 35990903
# Submitted job: scib 'tardis_sciplex' step 1674 trajectory 'all_data_included'
# Submitted batch job 35990904
# Submitted job: scib 'tardis_sciplex' step 1720 trajectory 'fork'
# Submitted batch job 35990905
# Submitted job: scib 'tardis_sciplex' step 1720 trajectory 'linear'
# Submitted batch job 35990906
# Submitted job: scib 'tardis_sciplex' step 1720 trajectory 'all_data_included'
# Submitted batch job 35990908
# Submitted job: scib 'tardis_sciplex' step 1767 trajectory 'fork'
# Submitted batch job 35990909
# Submitted job: scib 'tardis_sciplex' step 1767 trajectory 'linear'
# Submitted batch job 35990910
# Submitted job: scib 'tardis_sciplex' step 1767 trajectory 'all_data_included'
# Submitted batch job 35990911
# Submitted job: scib 'tardis_sciplex' step 1813 trajectory 'fork'
# Submitted batch job 35990912
# Submitted job: scib 'tardis_sciplex' step 1813 trajectory 'linear'
# Submitted batch job 35990913
# Submitted job: scib 'tardis_sciplex' step 1813 trajectory 'all_data_included'
# Submitted batch job 35990914
# Submitted job: scib 'tardis_sciplex' step 1860 trajectory 'fork'
# Submitted batch job 35990916
# Submitted job: scib 'tardis_sciplex' step 1860 trajectory 'linear'
# Submitted batch job 35990917
# Submitted job: scib 'tardis_sciplex' step 1860 trajectory 'all_data_included'
# Submitted batch job 35990918
# Submitted job: scib 'tardis_sciplex' step 1906 trajectory 'fork'
# Submitted batch job 35990919
# Submitted job: scib 'tardis_sciplex' step 1906 trajectory 'linear'
# Submitted batch job 35990921
# Submitted job: scib 'tardis_sciplex' step 1906 trajectory 'all_data_included'
# Submitted batch job 35990922
# Submitted job: scib 'tardis_sciplex' step 1953 trajectory 'fork'
# Submitted batch job 35990923
# Submitted job: scib 'tardis_sciplex' step 1953 trajectory 'linear'
# Submitted batch job 35990924
# Submitted job: scib 'tardis_sciplex' step 1953 trajectory 'all_data_included'
# Submitted batch job 35990926
# Submitted job: scib 'tardis_sciplex' step 1999 trajectory 'fork'
# Submitted batch job 35990927
# Submitted job: scib 'tardis_sciplex' step 1999 trajectory 'linear'
# Submitted batch job 35990928
# Submitted job: scib 'tardis_sciplex' step 1999 trajectory 'all_data_included'
# Submitted batch job 35990929
# Submitted job: scib 'tardis_sciplex' step 2046 trajectory 'fork'
# Submitted batch job 35990931
# Submitted job: scib 'tardis_sciplex' step 2046 trajectory 'linear'
# Submitted batch job 35990932
# Submitted job: scib 'tardis_sciplex' step 2046 trajectory 'all_data_included'
# Submitted batch job 35990933
# Submitted job: scib 'tardis_sciplex' step 2092 trajectory 'fork'
# Submitted batch job 35990934
# Submitted job: scib 'tardis_sciplex' step 2092 trajectory 'linear'
# Submitted batch job 35990935
# Submitted job: scib 'tardis_sciplex' step 2092 trajectory 'all_data_included'
# Submitted batch job 35990937
# Submitted job: scib 'tardis_sciplex' step 2139 trajectory 'fork'
# Submitted batch job 35990938
# Submitted job: scib 'tardis_sciplex' step 2139 trajectory 'linear'
# Submitted batch job 35990939
# Submitted job: scib 'tardis_sciplex' step 2139 trajectory 'all_data_included'
# Submitted batch job 35990940
# Submitted job: scib 'tardis_sciplex' step 2185 trajectory 'fork'
# Submitted batch job 35990941
# Submitted job: scib 'tardis_sciplex' step 2185 trajectory 'linear'
# Submitted batch job 35990942
# Submitted job: scib 'tardis_sciplex' step 2185 trajectory 'all_data_included'
# Submitted batch job 35990943
# Submitted job: scib 'tardis_sciplex' step 2232 trajectory 'fork'
# Submitted batch job 35990944
# Submitted job: scib 'tardis_sciplex' step 2232 trajectory 'linear'
# Submitted batch job 35990945
# Submitted job: scib 'tardis_sciplex' step 2232 trajectory 'all_data_included'
# Submitted batch job 35990946
# Submitted job: scib 'tardis_sciplex' step 2278 trajectory 'fork'
# Submitted batch job 35990947
# Submitted job: scib 'tardis_sciplex' step 2278 trajectory 'linear'
# Submitted batch job 35990948
# Submitted job: scib 'tardis_sciplex' step 2278 trajectory 'all_data_included'
# Submitted batch job 35990949
# Submitted job: scib 'tardis_sciplex' step 2325 trajectory 'fork'
# Submitted batch job 35990950
# Submitted job: scib 'tardis_sciplex' step 2325 trajectory 'linear'
# Submitted batch job 35990951
# Submitted job: scib 'tardis_sciplex' step 2325 trajectory 'all_data_included'
# Submitted batch job 35990952
# Submitted job: scib 'tardis_sciplex' step 2371 trajectory 'fork'
# Submitted batch job 35990953
# Submitted job: scib 'tardis_sciplex' step 2371 trajectory 'linear'
# Submitted batch job 35990954
# Submitted job: scib 'tardis_sciplex' step 2371 trajectory 'all_data_included'
# Submitted batch job 35990955
# Submitted job: scib 'tardis_sciplex' step 2418 trajectory 'fork'
# Submitted batch job 35990956
# Submitted job: scib 'tardis_sciplex' step 2418 trajectory 'linear'
# Submitted batch job 35990957
# Submitted job: scib 'tardis_sciplex' step 2418 trajectory 'all_data_included'
# Submitted batch job 35990958
# Submitted job: scib 'tardis_sciplex' step 2464 trajectory 'fork'
# Submitted batch job 35990959
# Submitted job: scib 'tardis_sciplex' step 2464 trajectory 'linear'
# Submitted batch job 35990960
# Submitted job: scib 'tardis_sciplex' step 2464 trajectory 'all_data_included'
# Submitted batch job 35990961
# Submitted job: scib 'tardis_sciplex' step 2511 trajectory 'fork'
# Submitted batch job 35990962
# Submitted job: scib 'tardis_sciplex' step 2511 trajectory 'linear'
# Submitted batch job 35990963
# Submitted job: scib 'tardis_sciplex' step 2511 trajectory 'all_data_included'
# Submitted batch job 35990964
# Submitted job: scib 'tardis_sciplex' step 2557 trajectory 'fork'
# Submitted batch job 35990965
# Submitted job: scib 'tardis_sciplex' step 2557 trajectory 'linear'
# Submitted batch job 35990966
# Submitted job: scib 'tardis_sciplex' step 2557 trajectory 'all_data_included'
# Submitted batch job 35990967
# Submitted job: scib 'tardis_sciplex' step 2604 trajectory 'fork'
# Submitted batch job 35990968
# Submitted job: scib 'tardis_sciplex' step 2604 trajectory 'linear'
# Submitted batch job 35990969
# Submitted job: scib 'tardis_sciplex' step 2604 trajectory 'all_data_included'
# Submitted batch job 35990970
# Submitted job: scib 'tardis_sciplex' step 2650 trajectory 'fork'
# Submitted batch job 35990971
# Submitted job: scib 'tardis_sciplex' step 2650 trajectory 'linear'
# Submitted batch job 35990972
# Submitted job: scib 'tardis_sciplex' step 2650 trajectory 'all_data_included'
# Submitted batch job 35990973
# Submitted job: scib 'tardis_sciplex' step 2697 trajectory 'fork'
# Submitted batch job 35990974
# Submitted job: scib 'tardis_sciplex' step 2697 trajectory 'linear'
# Submitted batch job 35990975
# Submitted job: scib 'tardis_sciplex' step 2697 trajectory 'all_data_included'
# Submitted batch job 35990976
# Submitted job: scib 'tardis_sciplex' step 2743 trajectory 'fork'
# Submitted batch job 35990977
# Submitted job: scib 'tardis_sciplex' step 2743 trajectory 'linear'
# Submitted batch job 35990978
# Submitted job: scib 'tardis_sciplex' step 2743 trajectory 'all_data_included'
# Submitted batch job 35990979
# Submitted job: scib 'tardis_sciplex' step 2790 trajectory 'fork'
# Submitted batch job 35990980
# Submitted job: scib 'tardis_sciplex' step 2790 trajectory 'linear'
# Submitted batch job 35990981
# Submitted job: scib 'tardis_sciplex' step 2790 trajectory 'all_data_included'
# Submitted batch job 35990982
# Submitted job: scib 'tardis_sciplex' step 2836 trajectory 'fork'
# Submitted batch job 35990983
# Submitted job: scib 'tardis_sciplex' step 2836 trajectory 'linear'
# Submitted batch job 35990984
# Submitted job: scib 'tardis_sciplex' step 2836 trajectory 'all_data_included'
# Submitted batch job 35990985
# Submitted job: scib 'tardis_sciplex' step 2883 trajectory 'fork'
# Submitted batch job 35990986
# Submitted job: scib 'tardis_sciplex' step 2883 trajectory 'linear'
# Submitted batch job 35990987
# Submitted job: scib 'tardis_sciplex' step 2883 trajectory 'all_data_included'
# Submitted batch job 35990988
# Submitted job: scib 'tardis_sciplex' step 2929 trajectory 'fork'
# Submitted batch job 35990989
# Submitted job: scib 'tardis_sciplex' step 2929 trajectory 'linear'
# Submitted batch job 35990990
# Submitted job: scib 'tardis_sciplex' step 2929 trajectory 'all_data_included'
# Submitted batch job 35990991
# Submitted job: scib 'tardis_sciplex' step 2976 trajectory 'fork'
# Submitted batch job 35990992
# Submitted job: scib 'tardis_sciplex' step 2976 trajectory 'linear'
# Submitted batch job 35990993
# Submitted job: scib 'tardis_sciplex' step 2976 trajectory 'all_data_included'
# Submitted batch job 35990994
# Submitted job: scib 'tardis_sciplex' step 3022 trajectory 'fork'
# Submitted batch job 35990996
# Submitted job: scib 'tardis_sciplex' step 3022 trajectory 'linear'
# Submitted batch job 35990997
# Submitted job: scib 'tardis_sciplex' step 3022 trajectory 'all_data_included'
# Submitted batch job 35990998
# Submitted job: scib 'tardis_sciplex' step 3069 trajectory 'fork'
# Submitted batch job 35990999
# Submitted job: scib 'tardis_sciplex' step 3069 trajectory 'linear'
# Submitted batch job 35991000
# Submitted job: scib 'tardis_sciplex' step 3069 trajectory 'all_data_included'
# Submitted batch job 35991002
# Submitted job: scib 'tardis_sciplex' step 3115 trajectory 'fork'
# Submitted batch job 35991003
# Submitted job: scib 'tardis_sciplex' step 3115 trajectory 'linear'
# Submitted batch job 35991004
# Submitted job: scib 'tardis_sciplex' step 3115 trajectory 'all_data_included'
# Submitted batch job 35991005
# Submitted job: scib 'tardis_sciplex' step 3162 trajectory 'fork'
# Submitted batch job 35991006
# Submitted job: scib 'tardis_sciplex' step 3162 trajectory 'linear'
# Submitted batch job 35991007
# Submitted job: scib 'tardis_sciplex' step 3162 trajectory 'all_data_included'
# Submitted batch job 35991009
# Submitted job: scib 'tardis_sciplex' step 3208 trajectory 'fork'
# Submitted batch job 35991010
# Submitted job: scib 'tardis_sciplex' step 3208 trajectory 'linear'
# Submitted batch job 35991011
# Submitted job: scib 'tardis_sciplex' step 3208 trajectory 'all_data_included'
# Submitted batch job 35991012
# Submitted job: scib 'tardis_sciplex' step 3255 trajectory 'fork'
# Submitted batch job 35991013
# Submitted job: scib 'tardis_sciplex' step 3255 trajectory 'linear'
# Submitted batch job 35991014
# Submitted job: scib 'tardis_sciplex' step 3255 trajectory 'all_data_included'
# Submitted batch job 35991015
# Submitted job: scib 'tardis_sciplex' step 3301 trajectory 'fork'
# Submitted batch job 35991016
# Submitted job: scib 'tardis_sciplex' step 3301 trajectory 'linear'
# Submitted batch job 35991017
# Submitted job: scib 'tardis_sciplex' step 3301 trajectory 'all_data_included'
# Submitted batch job 35991018
# Submitted job: scib 'tardis_sciplex' step 3348 trajectory 'fork'
# Submitted batch job 35991019
# Submitted job: scib 'tardis_sciplex' step 3348 trajectory 'linear'
# Submitted batch job 35991020
# Submitted job: scib 'tardis_sciplex' step 3348 trajectory 'all_data_included'
# Submitted batch job 35991021
# Submitted job: scib 'tardis_sciplex' step 3394 trajectory 'fork'
# Submitted batch job 35991022
# Submitted job: scib 'tardis_sciplex' step 3394 trajectory 'linear'
# Submitted batch job 35991023
# Submitted job: scib 'tardis_sciplex' step 3394 trajectory 'all_data_included'
# Submitted batch job 35991024
# Submitted job: scib 'tardis_sciplex' step 3441 trajectory 'fork'
# Submitted batch job 35991025
# Submitted job: scib 'tardis_sciplex' step 3441 trajectory 'linear'
# Submitted batch job 35991026
# Submitted job: scib 'tardis_sciplex' step 3441 trajectory 'all_data_included'
# Submitted batch job 35991027
# Submitted job: scib 'tardis_sciplex' step 3487 trajectory 'fork'
# Submitted batch job 35991028
# Submitted job: scib 'tardis_sciplex' step 3487 trajectory 'linear'
# Submitted batch job 35991029
# Submitted job: scib 'tardis_sciplex' step 3487 trajectory 'all_data_included'
# Submitted batch job 35991030
# Submitted job: scib 'tardis_sciplex' step 3534 trajectory 'fork'
# Submitted batch job 35991031
# Submitted job: scib 'tardis_sciplex' step 3534 trajectory 'linear'
# Submitted batch job 35991032
# Submitted job: scib 'tardis_sciplex' step 3534 trajectory 'all_data_included'
# Submitted batch job 35991033
# Submitted job: scib 'tardis_sciplex' step 3580 trajectory 'fork'
# Submitted batch job 35991034
# Submitted job: scib 'tardis_sciplex' step 3580 trajectory 'linear'
# Submitted batch job 35991035
# Submitted job: scib 'tardis_sciplex' step 3580 trajectory 'all_data_included'
# Submitted batch job 35991036
# Submitted job: scib 'tardis_sciplex' step 3627 trajectory 'fork'
# Submitted batch job 35991037
# Submitted job: scib 'tardis_sciplex' step 3627 trajectory 'linear'
# Submitted batch job 35991038
# Submitted job: scib 'tardis_sciplex' step 3627 trajectory 'all_data_included'
# Submitted batch job 35991039
# Submitted job: scib 'tardis_sciplex' step 3673 trajectory 'fork'
# Submitted batch job 35991040
# Submitted job: scib 'tardis_sciplex' step 3673 trajectory 'linear'
# Submitted batch job 35991041
# Submitted job: scib 'tardis_sciplex' step 3673 trajectory 'all_data_included'
# Submitted batch job 35991042
# Submitted job: scib 'tardis_sciplex' step 3720 trajectory 'fork'
# Submitted batch job 35991043
# Submitted job: scib 'tardis_sciplex' step 3720 trajectory 'linear'
# Submitted batch job 35991044
# Submitted job: scib 'tardis_sciplex' step 3720 trajectory 'all_data_included'
# Submitted batch job 35991045
# Submitted job: scib 'tardis_sciplex' step 3766 trajectory 'fork'
# Submitted batch job 35991046
# Submitted job: scib 'tardis_sciplex' step 3766 trajectory 'linear'
# Submitted batch job 35991047
# Submitted job: scib 'tardis_sciplex' step 3766 trajectory 'all_data_included'
# Submitted batch job 35991048
# Submitted job: scib 'tardis_sciplex' step 3813 trajectory 'fork'
# Submitted batch job 35991049
# Submitted job: scib 'tardis_sciplex' step 3813 trajectory 'linear'
# Submitted batch job 35991050
# Submitted job: scib 'tardis_sciplex' step 3813 trajectory 'all_data_included'
# Submitted batch job 35991051
# Submitted job: scib 'tardis_sciplex' step 3859 trajectory 'fork'
# Submitted batch job 35991052
# Submitted job: scib 'tardis_sciplex' step 3859 trajectory 'linear'
# Submitted batch job 35991053
# Submitted job: scib 'tardis_sciplex' step 3859 trajectory 'all_data_included'
# Submitted batch job 35991054
# Submitted job: scib 'tardis_sciplex' step 3906 trajectory 'fork'
# Submitted batch job 35991055
# Submitted job: scib 'tardis_sciplex' step 3906 trajectory 'linear'
# Submitted batch job 35991056
# Submitted job: scib 'tardis_sciplex' step 3906 trajectory 'all_data_included'
# Submitted batch job 35991057
# Submitted job: scib 'tardis_sciplex' step 3952 trajectory 'fork'
# Submitted batch job 35991058
# Submitted job: scib 'tardis_sciplex' step 3952 trajectory 'linear'
# Submitted batch job 35991059
# Submitted job: scib 'tardis_sciplex' step 3952 trajectory 'all_data_included'
# Submitted batch job 35991060
# Submitted job: scib 'tardis_sciplex' step 3999 trajectory 'fork'
# Submitted batch job 35991061
# Submitted job: scib 'tardis_sciplex' step 3999 trajectory 'linear'
# Submitted batch job 35991062
# Submitted job: scib 'tardis_sciplex' step 3999 trajectory 'all_data_included'
# Submitted batch job 35991063
# Submitted job: scib 'tardis_sciplex' step 4045 trajectory 'fork'
# Submitted batch job 35991064
# Submitted job: scib 'tardis_sciplex' step 4045 trajectory 'linear'
# Submitted batch job 35991065
# Submitted job: scib 'tardis_sciplex' step 4045 trajectory 'all_data_included'
# Submitted batch job 35991066
# Submitted job: scib 'tardis_sciplex' step 4092 trajectory 'fork'
# Submitted batch job 35991067
# Submitted job: scib 'tardis_sciplex' step 4092 trajectory 'linear'
# Submitted batch job 35991068
# Submitted job: scib 'tardis_sciplex' step 4092 trajectory 'all_data_included'
# Submitted batch job 35991069
# Submitted job: scib 'tardis_sciplex' step 4138 trajectory 'fork'
# Submitted batch job 35991070
# Submitted job: scib 'tardis_sciplex' step 4138 trajectory 'linear'
# Submitted batch job 35991071
# Submitted job: scib 'tardis_sciplex' step 4138 trajectory 'all_data_included'
# Submitted batch job 35991072
# Submitted job: scib 'tardis_sciplex' step 4185 trajectory 'fork'
# Submitted batch job 35991073
# Submitted job: scib 'tardis_sciplex' step 4185 trajectory 'linear'
# Submitted batch job 35991074
# Submitted job: scib 'tardis_sciplex' step 4185 trajectory 'all_data_included'
# Submitted batch job 35991075
# Submitted job: scib 'tardis_sciplex' step 4231 trajectory 'fork'
# Submitted batch job 35991076
# Submitted job: scib 'tardis_sciplex' step 4231 trajectory 'linear'
# Submitted batch job 35991077
# Submitted job: scib 'tardis_sciplex' step 4231 trajectory 'all_data_included'
# Submitted batch job 35991078
# Submitted job: scib 'tardis_sciplex' step 4278 trajectory 'fork'
# Submitted batch job 35991079
# Submitted job: scib 'tardis_sciplex' step 4278 trajectory 'linear'
# Submitted batch job 35991080
# Submitted job: scib 'tardis_sciplex' step 4278 trajectory 'all_data_included'
# Submitted batch job 35991081
# Submitted job: scib 'tardis_sciplex' step 4324 trajectory 'fork'
# Submitted batch job 35991082
# Submitted job: scib 'tardis_sciplex' step 4324 trajectory 'linear'
# Submitted batch job 35991083
# Submitted job: scib 'tardis_sciplex' step 4324 trajectory 'all_data_included'
# Submitted batch job 35991084
# Submitted job: scib 'tardis_sciplex' step 4371 trajectory 'fork'
# Submitted batch job 35991085
# Submitted job: scib 'tardis_sciplex' step 4371 trajectory 'linear'
# Submitted batch job 35991086
# Submitted job: scib 'tardis_sciplex' step 4371 trajectory 'all_data_included'
# Submitted batch job 35991087
# Submitted job: scib 'tardis_sciplex' step 4417 trajectory 'fork'
# Submitted batch job 35991088
# Submitted job: scib 'tardis_sciplex' step 4417 trajectory 'linear'
# Submitted batch job 35991089
# Submitted job: scib 'tardis_sciplex' step 4417 trajectory 'all_data_included'
# Submitted batch job 35991090
# Submitted job: scib 'tardis_sciplex' step 4464 trajectory 'fork'
# Submitted batch job 35991091
# Submitted job: scib 'tardis_sciplex' step 4464 trajectory 'linear'
# Submitted batch job 35991092
# Submitted job: scib 'tardis_sciplex' step 4464 trajectory 'all_data_included'
# Submitted batch job 35991093
# Submitted job: scib 'tardis_sciplex' step 4510 trajectory 'fork'
# Submitted batch job 35991094
# Submitted job: scib 'tardis_sciplex' step 4510 trajectory 'linear'
# Submitted batch job 35991095
# Submitted job: scib 'tardis_sciplex' step 4510 trajectory 'all_data_included'
# Submitted batch job 35991096
# Submitted job: scib 'tardis_sciplex' step 4557 trajectory 'fork'
# Submitted batch job 35991097
# Submitted job: scib 'tardis_sciplex' step 4557 trajectory 'linear'
# Submitted batch job 35991098
# Submitted job: scib 'tardis_sciplex' step 4557 trajectory 'all_data_included'
# Submitted batch job 35991099
# Submitted job: scib 'tardis_sciplex' step 4603 trajectory 'fork'
# Submitted batch job 35991100
# Submitted job: scib 'tardis_sciplex' step 4603 trajectory 'linear'
# Submitted batch job 35991101
# Submitted job: scib 'tardis_sciplex' step 4603 trajectory 'all_data_included'
# Submitted batch job 35991102
# Submitted job: scib 'tardis_sciplex' step 4650 trajectory 'fork'
# Submitted batch job 35991103
# Submitted job: scib 'tardis_sciplex' step 4650 trajectory 'linear'
# Submitted batch job 35991104
# Submitted job: scib 'tardis_sciplex' step 4650 trajectory 'all_data_included'
# Submitted batch job 35991105
# Submitted job: scib 'tardis_sciplex' step 4696 trajectory 'fork'
# Submitted batch job 35991106
# Submitted job: scib 'tardis_sciplex' step 4696 trajectory 'linear'
# Submitted batch job 35991107
# Submitted job: scib 'tardis_sciplex' step 4696 trajectory 'all_data_included'
# Submitted batch job 35991108
# Submitted job: scib 'tardis_sciplex' step 4743 trajectory 'fork'
# Submitted batch job 35991109
# Submitted job: scib 'tardis_sciplex' step 4743 trajectory 'linear'
# Submitted batch job 35991110
# Submitted job: scib 'tardis_sciplex' step 4743 trajectory 'all_data_included'
# Submitted batch job 35991111
# Submitted job: scib 'tardis_sciplex' step 4789 trajectory 'fork'
# Submitted batch job 35991112
# Submitted job: scib 'tardis_sciplex' step 4789 trajectory 'linear'
# Submitted batch job 35991113
# Submitted job: scib 'tardis_sciplex' step 4789 trajectory 'all_data_included'
# Submitted batch job 35991114
# Submitted job: scib 'tardis_sciplex' step 4836 trajectory 'fork'
# Submitted batch job 35991115
# Submitted job: scib 'tardis_sciplex' step 4836 trajectory 'linear'
# Submitted batch job 35991116
# Submitted job: scib 'tardis_sciplex' step 4836 trajectory 'all_data_included'
# Submitted batch job 35991117
# Submitted job: scib 'tardis_sciplex' step 4882 trajectory 'fork'
# Submitted batch job 35991118
# Submitted job: scib 'tardis_sciplex' step 4882 trajectory 'linear'
# Submitted batch job 35991119
# Submitted job: scib 'tardis_sciplex' step 4882 trajectory 'all_data_included'
# Submitted batch job 35991120
# Submitted job: scib 'tardis_sciplex' step 4929 trajectory 'fork'
# Submitted batch job 35991121
# Submitted job: scib 'tardis_sciplex' step 4929 trajectory 'linear'
# Submitted batch job 35991122
# Submitted job: scib 'tardis_sciplex' step 4929 trajectory 'all_data_included'
# Submitted batch job 35991123
# Submitted job: scib 'tardis_sciplex' step 4975 trajectory 'fork'
# Submitted batch job 35991124
# Submitted job: scib 'tardis_sciplex' step 4975 trajectory 'linear'
# Submitted batch job 35991125
# Submitted job: scib 'tardis_sciplex' step 4975 trajectory 'all_data_included'
# Submitted batch job 35991126
# Submitted job: scib 'tardis_sciplex' step 5022 trajectory 'fork'
# Submitted batch job 35991127
# Submitted job: scib 'tardis_sciplex' step 5022 trajectory 'linear'
# Submitted batch job 35991128
# Submitted job: scib 'tardis_sciplex' step 5022 trajectory 'all_data_included'
# Submitted batch job 35991129
# Submitted job: scib 'tardis_sciplex' step 5068 trajectory 'fork'
# Submitted batch job 35991130
# Submitted job: scib 'tardis_sciplex' step 5068 trajectory 'linear'
# Submitted batch job 35991131
# Submitted job: scib 'tardis_sciplex' step 5068 trajectory 'all_data_included'
# Submitted batch job 35991132
# Submitted job: scib 'tardis_sciplex' step 5115 trajectory 'fork'
# Submitted batch job 35991133
# Submitted job: scib 'tardis_sciplex' step 5115 trajectory 'linear'
# Submitted batch job 35991134
# Submitted job: scib 'tardis_sciplex' step 5115 trajectory 'all_data_included'
# Submitted batch job 35991135
# Submitted job: scib 'tardis_sciplex' step 5161 trajectory 'fork'
# Submitted batch job 35991136
# Submitted job: scib 'tardis_sciplex' step 5161 trajectory 'linear'
# Submitted batch job 35991137
# Submitted job: scib 'tardis_sciplex' step 5161 trajectory 'all_data_included'
# Submitted batch job 35991138
# Submitted job: scib 'tardis_sciplex' step 5208 trajectory 'fork'
# Submitted batch job 35991139
# Submitted job: scib 'tardis_sciplex' step 5208 trajectory 'linear'
# Submitted batch job 35991140
# Submitted job: scib 'tardis_sciplex' step 5208 trajectory 'all_data_included'
# Submitted batch job 35991141
# Submitted job: scib 'tardis_sciplex' step 5254 trajectory 'fork'
# Submitted batch job 35991142
# Submitted job: scib 'tardis_sciplex' step 5254 trajectory 'linear'
# Submitted batch job 35991143
# Submitted job: scib 'tardis_sciplex' step 5254 trajectory 'all_data_included'
# Submitted batch job 35991144
# Submitted job: scib 'tardis_sciplex' step 5301 trajectory 'fork'
# Submitted batch job 35991145
# Submitted job: scib 'tardis_sciplex' step 5301 trajectory 'linear'
# Submitted batch job 35991146
# Submitted job: scib 'tardis_sciplex' step 5301 trajectory 'all_data_included'
# Submitted batch job 35991147
# Submitted job: scib 'tardis_sciplex' step 5347 trajectory 'fork'
# Submitted batch job 35991148
# Submitted job: scib 'tardis_sciplex' step 5347 trajectory 'linear'
# Submitted batch job 35991149
# Submitted job: scib 'tardis_sciplex' step 5347 trajectory 'all_data_included'
# Submitted batch job 35991150
# Submitted job: scib 'tardis_sciplex' step 5394 trajectory 'fork'
# Submitted batch job 35991151
# Submitted job: scib 'tardis_sciplex' step 5394 trajectory 'linear'
# Submitted batch job 35991152
# Submitted job: scib 'tardis_sciplex' step 5394 trajectory 'all_data_included'
# Submitted batch job 35991153
# Submitted job: scib 'tardis_sciplex' step 5440 trajectory 'fork'
# Submitted batch job 35991154
# Submitted job: scib 'tardis_sciplex' step 5440 trajectory 'linear'
# Submitted batch job 35991155
# Submitted job: scib 'tardis_sciplex' step 5440 trajectory 'all_data_included'
# Submitted batch job 35991156
# Submitted job: scib 'tardis_sciplex' step 5487 trajectory 'fork'
# Submitted batch job 35991157
# Submitted job: scib 'tardis_sciplex' step 5487 trajectory 'linear'
# Submitted batch job 35991158
# Submitted job: scib 'tardis_sciplex' step 5487 trajectory 'all_data_included'
# Submitted batch job 35991159
# Submitted job: scib 'tardis_sciplex' step 5533 trajectory 'fork'
# Submitted batch job 35991160
# Submitted job: scib 'tardis_sciplex' step 5533 trajectory 'linear'
# Submitted batch job 35991161
# Submitted job: scib 'tardis_sciplex' step 5533 trajectory 'all_data_included'
# Submitted batch job 35991162
# Submitted job: scib 'tardis_sciplex' step 5580 trajectory 'fork'
# Submitted batch job 35991163
# Submitted job: scib 'tardis_sciplex' step 5580 trajectory 'linear'
# Submitted batch job 35991164
# Submitted job: scib 'tardis_sciplex' step 5580 trajectory 'all_data_included'
# Submitted batch job 35991165
# Submitted job: scib 'tardis_sciplex' step 5626 trajectory 'fork'
# Submitted batch job 35991166
# Submitted job: scib 'tardis_sciplex' step 5626 trajectory 'linear'
# Submitted batch job 35991167
# Submitted job: scib 'tardis_sciplex' step 5626 trajectory 'all_data_included'
# Submitted batch job 35991168
# Submitted job: scib 'tardis_sciplex' step 5673 trajectory 'fork'
# Submitted batch job 35991169
# Submitted job: scib 'tardis_sciplex' step 5673 trajectory 'linear'
# Submitted batch job 35991170
# Submitted job: scib 'tardis_sciplex' step 5673 trajectory 'all_data_included'
# Submitted batch job 35991171
# Submitted job: scib 'tardis_sciplex' step 5719 trajectory 'fork'
# Submitted batch job 35991172
# Submitted job: scib 'tardis_sciplex' step 5719 trajectory 'linear'
# Submitted batch job 35991173
# Submitted job: scib 'tardis_sciplex' step 5719 trajectory 'all_data_included'
# Submitted batch job 35991174
# Submitted job: scib 'tardis_sciplex' step 5766 trajectory 'fork'
# Submitted batch job 35991175
# Submitted job: scib 'tardis_sciplex' step 5766 trajectory 'linear'
# Submitted batch job 35991176
# Submitted job: scib 'tardis_sciplex' step 5766 trajectory 'all_data_included'
# Submitted batch job 35991177
# Submitted job: scib 'tardis_sciplex' step 5812 trajectory 'fork'
# Submitted batch job 35991178
# Submitted job: scib 'tardis_sciplex' step 5812 trajectory 'linear'
# Submitted batch job 35991179
# Submitted job: scib 'tardis_sciplex' step 5812 trajectory 'all_data_included'
# Submitted batch job 35991180
# Submitted job: scib 'tardis_sciplex' step 5859 trajectory 'fork'
# Submitted batch job 35991181
# Submitted job: scib 'tardis_sciplex' step 5859 trajectory 'linear'
# Submitted batch job 35991182
# Submitted job: scib 'tardis_sciplex' step 5859 trajectory 'all_data_included'
# Submitted batch job 35991183
# Submitted job: scib 'tardis_sciplex' step 5905 trajectory 'fork'
# Submitted batch job 35991184
# Submitted job: scib 'tardis_sciplex' step 5905 trajectory 'linear'
# Submitted batch job 35991185
# Submitted job: scib 'tardis_sciplex' step 5905 trajectory 'all_data_included'
# Submitted batch job 35991186
# Submitted job: scib 'tardis_sciplex' step 5952 trajectory 'fork'
# Submitted batch job 35991187
# Submitted job: scib 'tardis_sciplex' step 5952 trajectory 'linear'
# Submitted batch job 35991188
# Submitted job: scib 'tardis_sciplex' step 5952 trajectory 'all_data_included'
# Submitted batch job 35991189
# Submitted job: scib 'tardis_sciplex' step 5998 trajectory 'fork'
# Submitted batch job 35991190
# Submitted job: scib 'tardis_sciplex' step 5998 trajectory 'linear'
# Submitted batch job 35991191
# Submitted job: scib 'tardis_sciplex' step 5998 trajectory 'all_data_included'
# Submitted batch job 35991192
# Submitted job: scib 'tardis_sciplex' step 6045 trajectory 'fork'
# Submitted batch job 35991193
# Submitted job: scib 'tardis_sciplex' step 6045 trajectory 'linear'
# Submitted batch job 35991194
# Submitted job: scib 'tardis_sciplex' step 6045 trajectory 'all_data_included'
# Submitted batch job 35991195
# Submitted job: scib 'tardis_sciplex' step 6091 trajectory 'fork'
# Submitted batch job 35991196
# Submitted job: scib 'tardis_sciplex' step 6091 trajectory 'linear'
# Submitted batch job 35991197
# Submitted job: scib 'tardis_sciplex' step 6091 trajectory 'all_data_included'
# Submitted batch job 35991198
# Submitted job: scib 'tardis_sciplex' step 6138 trajectory 'fork'
# Submitted batch job 35991199
# Submitted job: scib 'tardis_sciplex' step 6138 trajectory 'linear'
# Submitted batch job 35991200
# Submitted job: scib 'tardis_sciplex' step 6138 trajectory 'all_data_included'
# Submitted batch job 35991201
# Submitted job: scib 'tardis_sciplex' step 6184 trajectory 'fork'
# Submitted batch job 35991202
# Submitted job: scib 'tardis_sciplex' step 6184 trajectory 'linear'
# Submitted batch job 35991203
# Submitted job: scib 'tardis_sciplex' step 6184 trajectory 'all_data_included'
# Submitted batch job 35991204
# Submitted job: scib 'tardis_sciplex' step 6231 trajectory 'fork'
# Submitted batch job 35991205
# Submitted job: scib 'tardis_sciplex' step 6231 trajectory 'linear'
# Submitted batch job 35991206
# Submitted job: scib 'tardis_sciplex' step 6231 trajectory 'all_data_included'
# Submitted batch job 35991207
# Submitted job: scib 'tardis_sciplex' step 6277 trajectory 'fork'
# Submitted batch job 35991208
# Submitted job: scib 'tardis_sciplex' step 6277 trajectory 'linear'
# Submitted batch job 35991209
# Submitted job: scib 'tardis_sciplex' step 6277 trajectory 'all_data_included'
# Submitted batch job 35991210
# Submitted job: scib 'tardis_sciplex' step 6324 trajectory 'fork'
# Submitted batch job 35991211
# Submitted job: scib 'tardis_sciplex' step 6324 trajectory 'linear'
# Submitted batch job 35991212
# Submitted job: scib 'tardis_sciplex' step 6324 trajectory 'all_data_included'
# Submitted batch job 35991213
# Submitted job: scib 'tardis_sciplex' step 6370 trajectory 'fork'
# Submitted batch job 35991214
# Submitted job: scib 'tardis_sciplex' step 6370 trajectory 'linear'
# Submitted batch job 35991215
# Submitted job: scib 'tardis_sciplex' step 6370 trajectory 'all_data_included'
# Submitted batch job 35991216
# Submitted job: scib 'tardis_sciplex' step 6417 trajectory 'fork'
# Submitted batch job 35991217
# Submitted job: scib 'tardis_sciplex' step 6417 trajectory 'linear'
# Submitted batch job 35991218
# Submitted job: scib 'tardis_sciplex' step 6417 trajectory 'all_data_included'
# Submitted batch job 35991219
# Submitted job: scib 'tardis_sciplex' step 6463 trajectory 'fork'
# Submitted batch job 35991220
# Submitted job: scib 'tardis_sciplex' step 6463 trajectory 'linear'
# Submitted batch job 35991221
# Submitted job: scib 'tardis_sciplex' step 6463 trajectory 'all_data_included'
# Submitted batch job 35991222
# Submitted job: scib 'tardis_sciplex' step 6510 trajectory 'fork'
# Submitted batch job 35991223
# Submitted job: scib 'tardis_sciplex' step 6510 trajectory 'linear'
# Submitted batch job 35991224
# Submitted job: scib 'tardis_sciplex' step 6510 trajectory 'all_data_included'
# Submitted batch job 35991225
# Submitted job: scib 'tardis_sciplex' step 6556 trajectory 'fork'
# Submitted batch job 35991226
# Submitted job: scib 'tardis_sciplex' step 6556 trajectory 'linear'
# Submitted batch job 35991227
# Submitted job: scib 'tardis_sciplex' step 6556 trajectory 'all_data_included'
# Submitted batch job 35991228
# Submitted job: scib 'tardis_sciplex' step 6603 trajectory 'fork'
# Submitted batch job 35991229
# Submitted job: scib 'tardis_sciplex' step 6603 trajectory 'linear'
# Submitted batch job 35991230
# Submitted job: scib 'tardis_sciplex' step 6603 trajectory 'all_data_included'
# Submitted batch job 35991231
# Submitted job: scib 'tardis_sciplex' step 6649 trajectory 'fork'
# Submitted batch job 35991232
# Submitted job: scib 'tardis_sciplex' step 6649 trajectory 'linear'
# Submitted batch job 35991233
# Submitted job: scib 'tardis_sciplex' step 6649 trajectory 'all_data_included'
# Submitted batch job 35991234
# Submitted job: scib 'tardis_sciplex' step 6696 trajectory 'fork'
# Submitted batch job 35991235
# Submitted job: scib 'tardis_sciplex' step 6696 trajectory 'linear'
# Submitted batch job 35991236
# Submitted job: scib 'tardis_sciplex' step 6696 trajectory 'all_data_included'
# Submitted batch job 35991237
# Submitted job: scib 'tardis_sciplex' step 6742 trajectory 'fork'
# Submitted batch job 35991238
# Submitted job: scib 'tardis_sciplex' step 6742 trajectory 'linear'
# Submitted batch job 35991239
# Submitted job: scib 'tardis_sciplex' step 6742 trajectory 'all_data_included'
# Submitted batch job 35991240
# Submitted job: scib 'tardis_sciplex' step 6789 trajectory 'fork'
# Submitted batch job 35991241
# Submitted job: scib 'tardis_sciplex' step 6789 trajectory 'linear'
# Submitted batch job 35991242
# Submitted job: scib 'tardis_sciplex' step 6789 trajectory 'all_data_included'
# Submitted batch job 35991243
# Submitted job: scib 'tardis_sciplex' step 6835 trajectory 'fork'
# Submitted batch job 35991244
# Submitted job: scib 'tardis_sciplex' step 6835 trajectory 'linear'
# Submitted batch job 35991245
# Submitted job: scib 'tardis_sciplex' step 6835 trajectory 'all_data_included'
# Submitted batch job 35991246
# Submitted job: scib 'tardis_sciplex' step 6882 trajectory 'fork'
# Submitted batch job 35991247
# Submitted job: scib 'tardis_sciplex' step 6882 trajectory 'linear'
# Submitted batch job 35991248
# Submitted job: scib 'tardis_sciplex' step 6882 trajectory 'all_data_included'
# Submitted batch job 35991249
# Submitted job: scib 'tardis_sciplex' step 6928 trajectory 'fork'
# Submitted batch job 35991250
# Submitted job: scib 'tardis_sciplex' step 6928 trajectory 'linear'
# Submitted batch job 35991251
# Submitted job: scib 'tardis_sciplex' step 6928 trajectory 'all_data_included'
# Submitted batch job 35991252
# Submitted job: scib 'tardis_sciplex' step 6975 trajectory 'fork'
# Submitted batch job 35991253
# Submitted job: scib 'tardis_sciplex' step 6975 trajectory 'linear'
# Submitted batch job 35991254
# Submitted job: scib 'tardis_sciplex' step 6975 trajectory 'all_data_included'
# Submitted batch job 35991255
# Submitted job: scib 'tardis_sciplex' step 7021 trajectory 'fork'
# Submitted batch job 35991256
# Submitted job: scib 'tardis_sciplex' step 7021 trajectory 'linear'
# Submitted batch job 35991257
# Submitted job: scib 'tardis_sciplex' step 7021 trajectory 'all_data_included'
# Submitted batch job 35991258
# Submitted job: scib 'tardis_sciplex' step 7068 trajectory 'fork'
# Submitted batch job 35991259
# Submitted job: scib 'tardis_sciplex' step 7068 trajectory 'linear'
# Submitted batch job 35991260
# Submitted job: scib 'tardis_sciplex' step 7068 trajectory 'all_data_included'
# Submitted batch job 35991261
# Submitted job: scib 'tardis_sciplex' step 7114 trajectory 'fork'
# Submitted batch job 35991262
# Submitted job: scib 'tardis_sciplex' step 7114 trajectory 'linear'
# Submitted batch job 35991263
# Submitted job: scib 'tardis_sciplex' step 7114 trajectory 'all_data_included'
# Submitted batch job 35991264
# Submitted job: scib 'tardis_sciplex' step 7161 trajectory 'fork'
# Submitted batch job 35991265
# Submitted job: scib 'tardis_sciplex' step 7161 trajectory 'linear'
# Submitted batch job 35991266
# Submitted job: scib 'tardis_sciplex' step 7161 trajectory 'all_data_included'
# Submitted batch job 35991267
# Submitted job: scib 'tardis_sciplex' step 7207 trajectory 'fork'
# Submitted batch job 35991268
# Submitted job: scib 'tardis_sciplex' step 7207 trajectory 'linear'
# Submitted batch job 35991269
# Submitted job: scib 'tardis_sciplex' step 7207 trajectory 'all_data_included'
# Submitted batch job 35991270
# Submitted job: scib 'tardis_sciplex' step 7254 trajectory 'fork'
# Submitted batch job 35991271
# Submitted job: scib 'tardis_sciplex' step 7254 trajectory 'linear'
# Submitted batch job 35991272
# Submitted job: scib 'tardis_sciplex' step 7254 trajectory 'all_data_included'
# Submitted batch job 35991273
# Submitted job: scib 'tardis_sciplex' step 7300 trajectory 'fork'
# Submitted batch job 35991274
# Submitted job: scib 'tardis_sciplex' step 7300 trajectory 'linear'
# Submitted batch job 35991275
# Submitted job: scib 'tardis_sciplex' step 7300 trajectory 'all_data_included'
# Submitted batch job 35991276
# Submitted job: scib 'tardis_sciplex' step 7347 trajectory 'fork'
# Submitted batch job 35991277
# Submitted job: scib 'tardis_sciplex' step 7347 trajectory 'linear'
# Submitted batch job 35991278
# Submitted job: scib 'tardis_sciplex' step 7347 trajectory 'all_data_included'
# Submitted batch job 35991279
# Submitted job: scib 'tardis_sciplex' step 7393 trajectory 'fork'
# Submitted batch job 35991280
# Submitted job: scib 'tardis_sciplex' step 7393 trajectory 'linear'
# Submitted batch job 35991281
# Submitted job: scib 'tardis_sciplex' step 7393 trajectory 'all_data_included'
# Submitted batch job 35991282
# Submitted job: scib 'tardis_sciplex' step 7440 trajectory 'fork'
# Submitted batch job 35991283
# Submitted job: scib 'tardis_sciplex' step 7440 trajectory 'linear'
# Submitted batch job 35991284
# Submitted job: scib 'tardis_sciplex' step 7440 trajectory 'all_data_included'
# Submitted batch job 35991285
# Submitted job: scib 'tardis_sciplex' step 7486 trajectory 'fork'
# Submitted batch job 35991286
# Submitted job: scib 'tardis_sciplex' step 7486 trajectory 'linear'
# Submitted batch job 35991287
# Submitted job: scib 'tardis_sciplex' step 7486 trajectory 'all_data_included'
# Submitted batch job 35991288
# Submitted job: scib 'tardis_sciplex' step 7533 trajectory 'fork'
# Submitted batch job 35991289
# Submitted job: scib 'tardis_sciplex' step 7533 trajectory 'linear'
# Submitted batch job 35991290
# Submitted job: scib 'tardis_sciplex' step 7533 trajectory 'all_data_included'
# Submitted batch job 35991291
# Submitted job: scib 'tardis_sciplex' step 7579 trajectory 'fork'
# Submitted batch job 35991292
# Submitted job: scib 'tardis_sciplex' step 7579 trajectory 'linear'
# Submitted batch job 35991293
# Submitted job: scib 'tardis_sciplex' step 7579 trajectory 'all_data_included'
# Submitted batch job 35991294
# Submitted job: scib 'tardis_sciplex' step 7626 trajectory 'fork'
# Submitted batch job 35991295
# Submitted job: scib 'tardis_sciplex' step 7626 trajectory 'linear'
# Submitted batch job 35991296
# Submitted job: scib 'tardis_sciplex' step 7626 trajectory 'all_data_included'
# Submitted batch job 35991297
# Submitted job: scib 'tardis_sciplex' step 7672 trajectory 'fork'
# Submitted batch job 35991298
# Submitted job: scib 'tardis_sciplex' step 7672 trajectory 'linear'
# Submitted batch job 35991299
# Submitted job: scib 'tardis_sciplex' step 7672 trajectory 'all_data_included'
# Submitted batch job 35991300
# Submitted job: scib 'tardis_sciplex' step 7719 trajectory 'fork'
# Submitted batch job 35991301
# Submitted job: scib 'tardis_sciplex' step 7719 trajectory 'linear'
# Submitted batch job 35991302
# Submitted job: scib 'tardis_sciplex' step 7719 trajectory 'all_data_included'
# Submitted batch job 35991303
# Submitted job: scib 'tardis_sciplex' step 7765 trajectory 'fork'
# Submitted batch job 35991304
# Submitted job: scib 'tardis_sciplex' step 7765 trajectory 'linear'
# Submitted batch job 35991305
# Submitted job: scib 'tardis_sciplex' step 7765 trajectory 'all_data_included'
# Submitted batch job 35991306
# Submitted job: scib 'tardis_sciplex' step 7812 trajectory 'fork'
# Submitted batch job 35991307
# Submitted job: scib 'tardis_sciplex' step 7812 trajectory 'linear'
# Submitted batch job 35991308
# Submitted job: scib 'tardis_sciplex' step 7812 trajectory 'all_data_included'
# Submitted batch job 35991309
# Submitted job: scib 'tardis_sciplex' step 7858 trajectory 'fork'
# Submitted batch job 35991310
# Submitted job: scib 'tardis_sciplex' step 7858 trajectory 'linear'
# Submitted batch job 35991311
# Submitted job: scib 'tardis_sciplex' step 7858 trajectory 'all_data_included'
# Submitted batch job 35991312
# Submitted job: scib 'tardis_sciplex' step 7905 trajectory 'fork'
# Submitted batch job 35991313
# Submitted job: scib 'tardis_sciplex' step 7905 trajectory 'linear'
# Submitted batch job 35991314
# Submitted job: scib 'tardis_sciplex' step 7905 trajectory 'all_data_included'
# Submitted batch job 35991315
# Submitted job: scib 'tardis_sciplex' step 7951 trajectory 'fork'
# Submitted batch job 35991316
# Submitted job: scib 'tardis_sciplex' step 7951 trajectory 'linear'
# Submitted batch job 35991317
# Submitted job: scib 'tardis_sciplex' step 7951 trajectory 'all_data_included'
# Submitted batch job 35991318
# Submitted job: scib 'tardis_sciplex' step 7998 trajectory 'fork'
# Submitted batch job 35991319
# Submitted job: scib 'tardis_sciplex' step 7998 trajectory 'linear'
# Submitted batch job 35991320
# Submitted job: scib 'tardis_sciplex' step 7998 trajectory 'all_data_included'
# Submitted batch job 35991321
# Submitted job: scib 'tardis_sciplex' step 8044 trajectory 'fork'
# Submitted batch job 35991322
# Submitted job: scib 'tardis_sciplex' step 8044 trajectory 'linear'
# Submitted batch job 35991323
# Submitted job: scib 'tardis_sciplex' step 8044 trajectory 'all_data_included'
# Submitted batch job 35991324
# Submitted job: scib 'tardis_sciplex' step 8091 trajectory 'fork'
# Submitted batch job 35991325
# Submitted job: scib 'tardis_sciplex' step 8091 trajectory 'linear'
# Submitted batch job 35991326
# Submitted job: scib 'tardis_sciplex' step 8091 trajectory 'all_data_included'
# Submitted batch job 35991327
# Submitted job: scib 'tardis_sciplex' step 8137 trajectory 'fork'
# Submitted batch job 35991328
# Submitted job: scib 'tardis_sciplex' step 8137 trajectory 'linear'
# Submitted batch job 35991329
# Submitted job: scib 'tardis_sciplex' step 8137 trajectory 'all_data_included'
# Submitted batch job 35991330
# Submitted job: scib 'tardis_sciplex' step 8184 trajectory 'fork'
# Submitted batch job 35991331
# Submitted job: scib 'tardis_sciplex' step 8184 trajectory 'linear'
# Submitted batch job 35991332
# Submitted job: scib 'tardis_sciplex' step 8184 trajectory 'all_data_included'
# Submitted batch job 35991333
# Submitted job: scib 'tardis_sciplex' step 8230 trajectory 'fork'
# Submitted batch job 35991334
# Submitted job: scib 'tardis_sciplex' step 8230 trajectory 'linear'
# Submitted batch job 35991335
# Submitted job: scib 'tardis_sciplex' step 8230 trajectory 'all_data_included'
# Submitted batch job 35991336
# Submitted job: scib 'tardis_sciplex' step 8277 trajectory 'fork'
# Submitted batch job 35991337
# Submitted job: scib 'tardis_sciplex' step 8277 trajectory 'linear'
# Submitted batch job 35991338
# Submitted job: scib 'tardis_sciplex' step 8277 trajectory 'all_data_included'
# Submitted batch job 35991339
# Submitted job: scib 'tardis_sciplex' step 8323 trajectory 'fork'
# Submitted batch job 35991340
# Submitted job: scib 'tardis_sciplex' step 8323 trajectory 'linear'
# Submitted batch job 35991341
# Submitted job: scib 'tardis_sciplex' step 8323 trajectory 'all_data_included'
# Submitted batch job 35991342
# Submitted job: scib 'tardis_sciplex' step 8370 trajectory 'fork'
# Submitted batch job 35991343
# Submitted job: scib 'tardis_sciplex' step 8370 trajectory 'linear'
# Submitted batch job 35991344
# ...
# Already exist: scib 'scvi_dentategyrus' step 565 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 565 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 565 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 565 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 565 trajectory 'all_data_included'
# Submitted batch job 35991930
# Already exist: scib 'scvi_dentategyrus' step 580 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 580 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 580 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 580 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 580 trajectory 'all_data_included'
# Submitted batch job 35991931
# Already exist: scib 'scvi_dentategyrus' step 870 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 870 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 870 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 870 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 870 trajectory 'all_data_included'
# Submitted batch job 35991932
# Already exist: scib 'scvi_dentategyrus' step 1160 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 1160 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 1160 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 1160 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 1160 trajectory 'all_data_included'
# Submitted batch job 35991933
# Already exist: scib 'scvi_dentategyrus' step 1450 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 1450 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 1450 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 1450 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 1450 trajectory 'all_data_included'
# Submitted batch job 35991934
# Already exist: scib 'scvi_dentategyrus' step 1740 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 1740 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 1740 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 1740 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 1740 trajectory 'all_data_included'
# Submitted batch job 35991935
# Already exist: scib 'scvi_dentategyrus' step 2030 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 2030 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 2030 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 2030 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 2030 trajectory 'all_data_included'
# Submitted batch job 35991936
# Already exist: scib 'scvi_dentategyrus' step 2320 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 2320 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 2320 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 2320 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 2320 trajectory 'all_data_included'
# Submitted batch job 35991937
# Already exist: scib 'scvi_dentategyrus' step 2610 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 2610 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 2610 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 2610 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 2610 trajectory 'all_data_included'
# Submitted batch job 35991938
# Already exist: scib 'scvi_dentategyrus' step 2900 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 2900 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 2900 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 2900 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 2900 trajectory 'all_data_included'
# Submitted batch job 35991939
# Already exist: scib 'scvi_dentategyrus' step 3190 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 3190 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 3190 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 3190 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 3190 trajectory 'all_data_included'
# Submitted batch job 35991940
# Already exist: scib 'scvi_dentategyrus' step 3480 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 3480 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 3480 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 3480 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 3480 trajectory 'all_data_included'
# Submitted batch job 35991941
# Already exist: scib 'scvi_dentategyrus' step 3770 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 3770 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 3770 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 3770 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 3770 trajectory 'all_data_included'
# Submitted batch job 35991942
# Already exist: scib 'scvi_dentategyrus' step 4060 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 4060 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 4060 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 4060 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 4060 trajectory 'all_data_included'
# Submitted batch job 35991943
# Already exist: scib 'scvi_dentategyrus' step 4350 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 4350 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 4350 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 4350 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 4350 trajectory 'all_data_included'
# Submitted batch job 35991944
# Already exist: scib 'scvi_dentategyrus' step 4640 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 4640 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 4640 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 4640 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 4640 trajectory 'all_data_included'
# Submitted batch job 35991945
# Already exist: scib 'scvi_dentategyrus' step 4930 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 4930 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 4930 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 4930 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 4930 trajectory 'all_data_included'
# Submitted batch job 35991946
# Already exist: scib 'scvi_dentategyrus' step 5220 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 5220 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 5220 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 5220 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 5220 trajectory 'all_data_included'
# Submitted batch job 35991947
# Already exist: scib 'scvi_dentategyrus' step 5510 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 5510 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 5510 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 5510 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 5510 trajectory 'all_data_included'
# Submitted batch job 35991948
# Already exist: scib 'scvi_dentategyrus' step 5800 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 5800 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 5800 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 5800 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 5800 trajectory 'all_data_included'
# Submitted batch job 35991949
# Already exist: scib 'scvi_dentategyrus' step 6090 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 6090 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 6090 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 6090 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 6090 trajectory 'all_data_included'
# Submitted batch job 35991950
# Already exist: scib 'scvi_dentategyrus' step 6380 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 6380 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 6380 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 6380 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 6380 trajectory 'all_data_included'
# Submitted batch job 35991951
# Already exist: scib 'scvi_dentategyrus' step 6670 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 6670 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 6670 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 6670 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 6670 trajectory 'all_data_included'
# Submitted batch job 35991952
# Already exist: scib 'scvi_dentategyrus' step 6960 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 6960 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 6960 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 6960 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 6960 trajectory 'all_data_included'
# Submitted batch job 35991953
# Already exist: scib 'scvi_dentategyrus' step 7250 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 7250 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 7250 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 7250 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 7250 trajectory 'all_data_included'
# Submitted batch job 35991954
# Already exist: scib 'scvi_dentategyrus' step 7540 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 7540 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 7540 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 7540 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 7540 trajectory 'all_data_included'
# Submitted batch job 35991955
# Already exist: scib 'scvi_dentategyrus' step 7830 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 7830 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 7830 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 7830 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 7830 trajectory 'all_data_included'
# Submitted batch job 35991956
# Already exist: scib 'scvi_dentategyrus' step 8120 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 8120 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 8120 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 8120 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 8120 trajectory 'all_data_included'
# Submitted batch job 35991957
# Already exist: scib 'scvi_dentategyrus' step 8410 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 8410 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 8410 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 8410 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 8410 trajectory 'all_data_included'
# Submitted batch job 35991958
# Already exist: scib 'scvi_dentategyrus' step 8700 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 8700 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 8700 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 8700 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 8700 trajectory 'all_data_included'
# Submitted batch job 35991959
# Already exist: scib 'scvi_dentategyrus' step 8990 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 8990 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 8990 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 8990 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 8990 trajectory 'all_data_included'
# Submitted batch job 35991960
# Already exist: scib 'scvi_dentategyrus' step 9280 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 9280 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 9280 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 9280 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 9280 trajectory 'all_data_included'
# Submitted batch job 35991961
# Already exist: scib 'scvi_dentategyrus' step 9570 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 9570 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 9570 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 9570 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 9570 trajectory 'all_data_included'
# Submitted batch job 35991962
# Already exist: scib 'scvi_dentategyrus' step 9860 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 9860 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 9860 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 9860 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 9860 trajectory 'all_data_included'
# Submitted batch job 35991963
# Already exist: scib 'scvi_dentategyrus' step 10150 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 10150 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 10150 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 10150 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 10150 trajectory 'all_data_included'
# Submitted batch job 35991964
# Already exist: scib 'scvi_dentategyrus' step 10440 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 10440 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 10440 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 10440 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 10440 trajectory 'all_data_included'
# Submitted batch job 35991965
# Already exist: scib 'scvi_dentategyrus' step 10730 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 10730 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 10730 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 10730 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 10730 trajectory 'all_data_included'
# Submitted batch job 35991966
# Already exist: scib 'scvi_dentategyrus' step 11020 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 11020 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 11020 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 11020 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 11020 trajectory 'all_data_included'
# Submitted batch job 35991967
# Already exist: scib 'scvi_dentategyrus' step 11310 trajectory 'complex'
# Already exist: scib 'scvi_dentategyrus' step 11310 trajectory 'less_complex_1'
# Already exist: scib 'scvi_dentategyrus' step 11310 trajectory 'less_complex_2'
# Already exist: scib 'scvi_dentategyrus' step 11310 trajectory 'linear_1'
# Submitted job: scib 'scvi_dentategyrus' step 11310 trajectory 'all_data_included'
# Submitted batch job 35991968
#  - Number of jobs submitted: 1106

# %%
definitions_path = os.path.join(dataset_dir, f"incremental_analysis_definitions_dict.pkl")
with open(definitions_path, "wb") as _f:
    pickle.dump(definitions, _f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
1
# Out:
# 1
