# %% [markdown]
# # scVI scANVI Training for Garcia dataset

# %%
0
# Out:
# 0

# %%
import sys

working_directory = "/home/icb/kemal.inecik/work/codes/sctram"
sys.path.append(working_directory)

# %%
import copy
import gc
import itertools
import os
import subprocess
import sys
import time
import warnings
from pathlib import Path

import scvi
import anndata as ad
import networkx as nx
import numpy as np
import pandas as pd
import scanpy as sc
import scipy.stats
import torch
from sklearn.neighbors import kneighbors_graph
import lightning.pytorch as pl
import torch
import anndata as ad

# %%
from helper.callbacks import EpochStepLogger, LatentOnIndexCallback, allow_untrained
from sctram.generate.real import sc_garcia_developmental_complete

sys.path.append("/home/icb/kemal.inecik/work/codes/sctram/reproducibility/server_sync/experiments")
from development_atlas_figure.helper.csv_operations import (
    harmonize_union_with_report,
    analyze_column_consistency,
    combine_dataframes_on_columns
)

# %%
# Important to have consistent figures across platforms

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import matplotlib.pyplot as plt
import seaborn as sns
import pickle

_rcparams_path = "/home/icb/kemal.inecik/work/codes/tardis/training/local/figures/rcparams.pickle"
with open(_rcparams_path, 'rb') as file:
    _rcparams = pickle.load(file)

plt.rcParams.update(_rcparams)

# %%
print(f"CUDA used: {torch.cuda.is_available()}")

dataset_dir = "/home/icb/kemal.inecik/lustre_workspace/temp_sctram_data"
helpers_directory = os.path.join(os.getcwd(), "helper")
logs_directory = os.path.join(os.getcwd(), "logs")
# Out:
# CUDA used: True

# %%
adata = sc_garcia_developmental_complete(dataset_dir=dataset_dir)

trajectory_annotation_csv_path = dict(
    germline = '/lustre/groups/ml01/workspace/kemal.inecik/hdca/data/metadata/partial_annotation_for_trajectory/Germline_harm_20250407.csv',
    haem = '/lustre/groups/ml01/workspace/kemal.inecik/hdca/data/metadata/partial_annotation_for_trajectory/Haem_harm_20250407.csv',
    pns_neuro_glia = '/lustre/groups/ml01/workspace/kemal.inecik/hdca/data/metadata/partial_annotation_for_trajectory/PNS_neuro_glia_harm_20250407.csv',
)

trajectory_annotation_csv = dict()
for i, j in trajectory_annotation_csv_path.items():
    k = pd.read_csv(j)
    k.set_index("Unnamed: 0", drop=True, inplace=True, verify_integrity=True)
    k.index.name = None
    trajectory_annotation_csv[i] = k

intersecting_columns_csv, differing_columns_csv = analyze_column_consistency(trajectory_annotation_csv)
trajectory_annotation_csv_combined = combine_dataframes_on_columns(trajectory_annotation_csv, sorted(intersecting_columns_csv))
out_df, mismatch_df, missing_df = harmonize_union_with_report(trajectory_annotation_csv_combined, adata.obs.copy())

adata = adata[out_df.index]
adata.obs = out_df
# Out:
# 2025-05-09 09:00:36.943 | WARNING  | sctram.generate.real._download:download_dataset:105 - File PosixPath('/home/icb/kemal.inecik/lustre_workspace/temp_sctram_data/garcia_developmental_complete.h5ad') already exists. Skipping download.
# /tmp/ipykernel_1446177/1767563532.py:11: DtypeWarning: Columns (17,20,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   k = pd.read_csv(j)
# /tmp/ipykernel_1446177/1767563532.py:11: DtypeWarning: Columns (8,22,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   k = pd.read_csv(j)

# %%
def smart_subsample(adata, group_key="LVL3", max_cells_per_group=500, random_state=0):
    """
    Subsample overrepresented groups to 'max_cells_per_group' cells,
    retain all cells from underrepresented groups.
    """
    np.random.seed(random_state)
    groups = adata.obs[group_key]
    indices_to_keep = []

    for group in groups.unique():
        group_indices = adata.obs.index[groups == group].tolist()
        if len(group_indices) > max_cells_per_group:
            selected = np.random.choice(group_indices, max_cells_per_group, replace=False)
            indices_to_keep.extend(selected)
        else:
            indices_to_keep.extend(group_indices)

    return adata[indices_to_keep].copy()
# print()
# display(adata)
adata_ = smart_subsample(adata, max_cells_per_group=1000)
del adata_.obsm, adata_.uns, adata_.obsp
gc.collect();

# %%
# adata_.obs["LVL0"].value_counts()
adata = adata_.copy()
del adata_
gc.collect()
adata
# Out:
# AnnData object with n_obs × n_vars = 26185 × 8192
#     obs: 'LVL0', 'LVL1', 'LVL2', 'LVL3', 'age', 'anatomical_region', 'anatomical_region_level_2', 'author_batch', 'biological_unit', 'broad_anno', 'cell_enrichment', 'cell_type', 'concatenated_integration_covariates', 'doi', 'handle_anndata', 'institute', 'integration_biological_unit', 'integration_donor', 'integration_library_platform_coarse', 'integration_sample_status', 'lane_ID', 'leiden', 'library_platform', 'organ', 'original_author_annotation', 'protocol_tissue_dissociation', 'reads_processing', 'ref_anno1', 'ref_anno2', 'reference_genome', 'reference_genome_ensembl_release', 'sample_ID', 'sample_cultured', 'sample_status', 'sequencing_platform', 'sex', 'sex_inferred', 'strand_sequence', 'study', 'study_PI', 'subject_type', 'csv_key'

# %%
germline_cells = [
 'GC',
 'PGC',
 'oocyte',
 'oogonia',
 'oogonia_meiotic_1',
 'oogonia_meiotic_2',
 'pre_oocyte',
 'pre_spermatogonia'
]

# %%
step_per_epoch = 41  # gotten from the callback
print(step_per_epoch)

epochs = list(itertools.chain(range(0, 10, 1), range(0, 400, 10)))
epochs = list(np.arange(0, 10, 0.1)) + epochs
# epochs = [round(i, 2) for i in epochs]
steps = sorted(set([int(i*step_per_epoch) for i in epochs]))

print(np.array(steps))
print(len(steps))
# Out:
# 41
# [    0     4     8    12    16    20    24    28    32    36    41    45
#     49    53    57    61    65    69    73    77    82    86    90    94
#     98   102   106   110   114   118   123   127   131   135   139   143
#    147   151   155   159   164   168   172   176   180   184   188   192
#    196   200   205   209   213   217   221   225   229   233   237   241
#    246   250   254   258   262   266   270   274   278   282   287   291
#    295   299   303   307   311   315   319   323   328   332   336   340
#    344   348   352   356   360   364   369   373   377   381   385   389
#    393   397   401   405   410   820  1230  1640  2050  2460  2870  3280
#   3690  4100  4510  4920  5330  5740  6150  6560  6970  7380  7790  8200
#   8610  9020  9430  9840 10250 10660 11070 11480 11890 12300 12710 13120
#  13530 13940 14350 14760 15170 15580 15990]
# 139

# %%
cb_latent = LatentOnIndexCallback(
    indices=steps,
    capture_by="step",
    adata=adata,
    subset_idx=None,
    latent_dir=dataset_dir,
    latent_base_name="scvi_garcia_incremental_with_callback"
)
logger_cb = EpochStepLogger()

model_params = dict(
    n_latent=24, 
    gene_likelihood = "nb",
)

train_params = dict(
    train_size=0.8,
    batch_size=512,
    limit_train_batches=1.00, 
    limit_val_batches=1.00,
    max_epochs=400,
)

dataset_params = dict(
    layer=None, 
    # labels_key="cell_type",
    # unlabeled_category="NA",
    batch_key="concatenated_integration_covariates",
    categorical_covariate_keys=None,
)

scvi.model.SCVI.setup_anndata(adata, **dataset_params)
vae = scvi.model.SCVI(adata, **model_params)
vae.train(**train_params, callbacks=[cb_latent])

model_dir_path = os.path.join(dataset_dir, f"scvi_garcia_incremental_with_callback")
vae.save(
    model_dir_path,
    overwrite=True,
)

pickle_paths_path = os.path.join(dataset_dir, f"scvi_garcia_incremental_with_callback_paths.pkl")
with open(pickle_paths_path, "wb") as f:
    pickle.dump(cb_latent.latents, f, protocol=pickle.HIGHEST_PROTOCOL)

# as it is modified
adata.obs.age = adata.obs.age.astype(str)
adata.write_h5ad(os.path.join(dataset_dir, f"scvi_garcia_incremental_with_callback_training_anndata.h5ad"))
    
# with open(pickle_paths_path, "rb") as f:
#     loaded_data: dict[str, str] = pickle.load(f)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# You are using a CUDA device ('NVIDIA A100-PCIE-40GB MIG 3g.20gb') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [MIG-3acbc457-82bc-59c2-a4db-9fd26324b7db]
# SLURM auto-requeueing enabled. Setting signal handlers.
# ...

# %%
with allow_untrained(vae):
    latent = ad.AnnData(X=vae.get_latent_representation())
latent.obs = adata.obs.copy()
sc.pp.neighbors(latent)
sc.tl.umap(latent)
latent_subset = latent[latent.obs.ref_anno2.isin(germline_cells)]

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    sc.pl.umap(
        latent,
        color=["age", "LVL0", "LVL1", "LVL2"],
        ncols=4,
        frameon=False,
        legend_fontsize="xx-small",
    )
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    sc.pl.umap(
        latent_subset,
        color=["age", "cell_type", "ref_anno2"],
        ncols=4,
        frameon=False,
        legend_fontsize="xx-small",
    )

# %% [markdown]
# # Resulting Latents

# %%
# for i, j in cb_latent.latents.items():
#     print(i)
#     latent = ad.read_h5ad(j)
#     latent.obs = adata.obs.copy()
#     sc.pp.neighbors(latent)
#     sc.tl.umap(latent)
#     latent_subset = latent[latent.obs.ref_anno2.isin(germline_cells)]

#     with warnings.catch_warnings():
#         warnings.simplefilter("ignore")
#         sc.pl.umap(
#             latent_subset,
#             color=["age", "cell_type", "ref_anno2"],
#             ncols=4,
#             frameon=False,
#             legend_fontsize="xx-small",
#             legend_loc="on data",
#             title=[i, i, i, i]
#         )

# %%
# latent = ad.read_h5ad(os.path.join(dataset_dir, "scvi_garcia_incremental_with_callback_step_410.h5ad"))
# latent.obs = adata.obs.copy()
# sc.pp.neighbors(latent)
# sc.tl.umap(latent)
# latent_subset = latent[latent.obs.ref_anno2.isin(germline_cells)]

# with warnings.catch_warnings():
#     warnings.simplefilter("ignore")
#     sc.pl.umap(
#         latent,
#         color=["age", "LVL0", "LVL1", "LVL2"],
#         ncols=4,
#         frameon=False,
#         legend_fontsize="xx-small",
#     )
# with warnings.catch_warnings():
#     warnings.simplefilter("ignore")
#     sc.pl.umap(
#         latent_subset,
#         color=["age", "cell_type", "ref_anno2"],
#         ncols=4,
#         frameon=False,
#         legend_fontsize="xx-small",
#         legend_loc="on data"
#     )
